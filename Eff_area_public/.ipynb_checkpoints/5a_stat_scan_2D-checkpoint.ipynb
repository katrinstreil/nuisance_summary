# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-11-2022)' )
# Out:
# loaded gammapy version: 0.1.dev19056+g5a5f803
# Supposed to be 1.0 (21-11-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map

from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit,  Parameters, Covariance , Parameter
from gammapy.datasets import MapDataset ,Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
    #PowerLawNuisanceSpectralModel,
    #PowerLawNormNuisanceSpectralModel
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

sys.path.append('/home/katrin/Documents/nuisance_summary/')
from Dataset_Creation import sys_dataset
import Dataset_load

# %% [markdown]
# ## Read dataset

# %%
dataset_asimov = Dataset_load.create_asimov()

# %% [markdown]
# ## Single Cases

# %%
true_energy = dataset_asimov.exposure.geom.axes[0].center.value
zero = 1e-24

shift = 0
tilt = 0
shift_assumed = 0.1
tilt_assumed = zero

print(tilt_neg)
sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = shift_neg, 
                        tilt = tilt_neg,
                        resolution = 0,
                       bias = 0,
                        e_reco_creation = 10, 
                        rnd = False)
dataset = sys_.create_dataset()
dataset.models[0].parameters['lon_0'].frozen = True
dataset.models[0].parameters['lat_0'].frozen = True
datasets = Datasets(dataset)    
    
    
dataset_N = sys_.create_dataset_N(10)
## addional parameter bias and resolution (ereco) but are frozen
penalising_invcovmatrix = np.zeros((4, 4))
np.fill_diagonal(penalising_invcovmatrix,
                 [1/zero**2, 1/zero**2, 1/shift_assumed**2, 1/tilt_assumed**2])

dataset_N.penalising_invcovmatrix = penalising_invcovmatrix
dataset_N.models[0].parameters['lon_0'].frozen = True
dataset_N.models[0].parameters['lat_0'].frozen = True
datasets_N = Datasets(dataset_N)

parlist= ['norm', 'tilt', 'sigma']
for p in parlist:
    dataset.models.parameters[p].frozen = True    
    dataset_N.models.parameters[p].frozen = True
# Out:
# -0.015
# compute exposure
# compute edisp
# 0.0
# compute exposure
# compute edisp
# 0.0

# %%
print(dataset)
# Out:
# MapDataset
# ----------
#
#   Name                            : 4yA_y9JE
#
#   Total counts                    : 361333
#   Total background counts         : 360331.31
#   Total excess counts             : 1001.76
#
#   Predicted counts                : 361257.24
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 925.89
#
#   Exposure min                    : 1.84e-01 m2 s
#   Exposure max                    : 2.34e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -753578.77
#
#   Number of models                : 2
#   Number of parameters            : 11
#   Number of free parameters       : 2
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                 (frozen):     83.631       deg
#       lat_0                 (frozen):     22.018       deg
#       sigma                 (frozen):      0.019       deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : 4yA_y9JE-bkg
#     Datasets names            : ['4yA_y9JE']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                  (frozen):      1.000
#       tilt                  (frozen):      0.000
#       reference             (frozen):      1.000       TeV

# %% [markdown]
# ## Standard

# %%
# %%time
fit = Fit(store_trace=False)
minuit_opts = {"tol": 0.01, "strategy": 2}
fit.optimize_opts = minuit_opts
result = fit.run(datasets)
print(result)
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 66
# 	total stat : -753580.09
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
# CPU times: user 486 ms, sys: 2.01 ms, total: 488 ms
# Wall time: 487 ms

# %%
fit.minuit
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = -7.536e+05                 │              Nfcn = 66               │
# │ EDM = 7.06e-05 (Goal: 2e-05)     │            time = 0.5 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────────────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name              │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────────────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_000_index     │   2.32    │   0.06    │            │            │         │         │       │
# │ 1 │ par_001_amplitude │    1.1    │    0.1    │            │            │         │         │       │
# └───┴───────────────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────────────────┬─────────────────────────────────────┐
# │                   │     par_000_index par_001_amplitude │
# ├───────────────────┼─────────────────────────────────────┤
# │     par_000_index │           0.00381           0.00424 │
# │ par_001_amplitude │           0.00424           0.00961 │
# └───────────────────┴─────────────────────────────────────┘

# %%
fit.minuit.draw_mnmatrix();

# %%
fit.minuit.parameters
# Out:
# ('par_000_index', 'par_001_amplitude')

# %%
# %%time
c = fit.minuit.draw_mncontour("par_000_index", "par_001_amplitude", 
                               cl = 0.68, 
                               size = 100, 
                               )
c95 = fit.minuit.draw_mncontour("par_000_index", "par_001_amplitude", 
                               cl = 0.95, 
                               size = 100, 
                               )
# Out:
# CPU times: user 6.45 s, sys: 184 ms, total: 6.63 s
# Wall time: 6.4 s

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Simplest default with labels')

# %%
cs_plot= plt.contour.ContourSet(ax=ax, 
                               levels= c.levels,
                               allkinds = c.allkinds)

# %%
type(c)
c.levels
c.allkinds
# Out:
# [[[1,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    2,
#    79]]]

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the contour set
cbar = fig.colorbar(c)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 5
#       2 fig, ax = plt.subplots()
#       4 # Plot the contour set
# ----> 5 cbar = fig.colorbar(c)
#       7 # Show the plot
#       8 plt.show()
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/figure.py:1281, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1277 NON_COLORBAR_KEYS = ['fraction', 'pad', 'shrink', 'aspect', 'anchor',
#    1278                      'panchor']
#    1279 cb_kw = {k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS}
# -> 1281 cb = cbar.Colorbar(cax, mappable, **cb_kw)
#    1283 if not userax:
#    1284     self.sca(current_ax)
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386     if is_varargs and arguments.get(name):
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/colorbar.py:396, in Colorbar.__init__(self, ax, mappable, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     394 else:
#     395     self._formatter = format  # Assume it is a Formatter or None
# --> 396 self._draw_all()
#     398 if isinstance(mappable, contour.ContourSet) and not mappable.filled:
#     399     self.add_lines(mappable)
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/colorbar.py:535, in Colorbar._draw_all(self)
#     533 self.vmin, self.vmax = self._boundaries[self._inside][[0, -1]]
#     534 # Compute the X/Y mesh.
# --> 535 X, Y = self._mesh()
#     536 # draw the extend triangles, and shrink the inner axes to accommodate.
#     537 # also adds the outline path to self.outline spine:
#     538 self._do_extends()
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/colorbar.py:1117, in Colorbar._mesh(self)
#    1110 def _mesh(self):
#    1111     """
#    1112     Return the coordinate arrays for the colorbar pcolormesh/patches.
#    1113
#    1114     These are scaled between vmin and vmax, and already handle colorbar
#    1115     orientation.
#    1116     """
# -> 1117     y, _ = self._proportional_y()
#    1118     # Use the vmin and vmax of the colorbar, which may not be the same
#    1119     # as the norm. There are situations where the colormap has a
#    1120     # narrower range than the colorbar and we want to accommodate the
#    1121     # extra contours.
#    1122     if (isinstance(self.norm, (colors.BoundaryNorm, colors.NoNorm))
#    1123             or self.boundaries is not None):
#    1124         # not using a norm.
#
# File ~/anaconda3/envs/gammapy-dev/lib/python3.8/site-packages/matplotlib/colorbar.py:1257, in Colorbar._proportional_y(self)
#    1254 yscaled = np.ma.filled(norm(yscaled), np.nan)
#    1255 # make the lower and upper extend lengths proportional to the lengths
#    1256 # of the first and last boundary spacing (if extendfrac='auto'):
# -> 1257 automin = yscaled[1] - yscaled[0]
#    1258 automax = yscaled[-1] - yscaled[-2]
#    1259 extendlength = [0, 0]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
c

# %%
cs = plt.contour(, (1, 2,3,4))  # these are not sigmas, just the contour values
plt.clabel(cs);

# %% [markdown]
# ## Nuisance Parameters

# %%
# %%time
fit_N = Fit(store_trace=False)
fit_N.optimize_opts = minuit_opts
result_N = fit_N.run([datasets_N[0]])
# Out:
# CPU times: user 2min 10s, sys: 11.1 s, total: 2min 21s
# Wall time: 2min 21s

# %% [markdown]
# # Stat Contours

# %%
# Out:
# x par_001_amplitude
# y par_000_index
# c; 0.3934693402873665
# E MnContours unable to find first two points
# []
# (0,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:2
#
# Cell In[15], line 12, in make_contours(fit, datasets, result, npoints, sigmas)
#      10     name1 = datasets.models.parameters_unique_names[idx1]
#      11     name2 = datasets.models.parameters_unique_names[idx2]
# ---> 12     contour = fit.stat_contour(
#      13         datasets=datasets,
#      14         x=datasets.parameters[par_1],
#      15         y=datasets.parameters[par_2],
#      16         numpoints=npoints,
#      17         sigma=sigma,
#      18     )
#      19     contours[f"contour_{par_1}_{par_2}"] = {
#      20         par_1: contour[name1].tolist(),
#      21         par_2: contour[name2].tolist(),
#      22     }
#      23 cts_sigma.append(contours)
#
# File ~/Documents/gammapy/gammapy/modeling/fit.py:499, in Fit.stat_contour(self, datasets, x, y, numpoints, sigma)
#     496 name_y = datasets.models.parameters_unique_names[i2]
#     498 with parameters.restore_status():
# --> 499     result = contour_iminuit(
#     500         parameters=parameters,
#     501         function=datasets.stat_sum,
#     502         x=x,
#     503         y=y,
#     504         numpoints=numpoints,
#     505         sigma=sigma,
#     506     )
#     508 x = result["x"] * x.scale
#     509 y = result["y"] * y.scale
#
# File ~/Documents/gammapy/gammapy/modeling/iminuit.py:179, in contour_iminuit(parameters, function, x, y, numpoints, sigma, **kwargs)
#     175 print(contour)
#     176 print(np.shape(contour))
#     177 return {
#     178     "success": True,
# --> 179     "x": contour[:, 0],
#     180     "y": contour[:, 1],
#     181 }
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
result.success
# Out:
# False

# %%
pars = {
    "phi": r"$\phi_0 \,/\,(10^{-11}\,{\rm TeV}^{-1} \, {\rm cm}^{-2} {\rm s}^{-1})$",
    "alpha": r"$\alpha$",
    "beta": r"$\beta$",
}

panels = [
    {
        "x": "alpha",
        "y": "phi",
        "cx": (lambda ct: ct["contour_alpha_amplitude"]["alpha"]),
        "cy": (lambda ct: np.array(1e11) * ct["contour_alpha_amplitude"]["amplitude"]),
    },
    {
        "x": "beta",
        "y": "phi",
        "cx": (lambda ct: ct["contour_beta_amplitude"]["beta"]),
        "cy": (lambda ct: np.array(1e11) * ct["contour_beta_amplitude"]["amplitude"]),
    },
    {
        "x": "alpha",
        "y": "beta",
        "cx": (lambda ct: ct["contour_alpha_beta"]["alpha"]),
        "cy": (lambda ct: ct["contour_alpha_beta"]["beta"]),
    },
]

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
colors = ["m", "b", "c"]
for p, ax in zip(panels, axes):
    xlabel = pars[p["x"]]
    ylabel = pars[p["y"]]
    for ks in range(len(cts_sigma)):
        plot_contour_line(
            ax,
            p["cx"](cts_sigma[ks]),
            p["cy"](cts_sigma[ks]),
            lw=2.5,
            color=colors[ks],
            label=f"{sigmas[ks]}" + r"$\sigma$",
        )
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
plt.legend()
plt.tight_layout()

# %%
fit.minuit.parameters
# Out:
# ('par_000_index',
#  'par_001_amplitude',
#  'par_002_sigma',
#  'par_003_norm',
#  'par_004_tilt')

# %%
fit.minuit.draw_mncontour("par_004_tilt", "par_003_norm", cl=(0.68, 0.9, 0.99));
# Out:
# E MnContours unable to find point on Contour 7
#  found only 6 points
