# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-12-2022)' )
# Out:
# loaded gammapy version: 1.1.dev320+g92a6eb9f4
# Supposed to be 1.0 (21-12-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset , Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator
from gammapy.estimators import FluxPoints
from gammapy.estimators import  FluxPointsEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

#sys.path.append(
#    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
#)
#from my_dataset_maps_20 import MapDatasetNuisance
#from MapDatasetNuisanceE import MapDatasetNuisanceE
#from  my_fit_20 import Fit
from Dataset_Creation import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
source = 'Crab'
path = '/home/vault/caph/mppi062h/repositories/HESS_3Dbkg_syserror/2-error_in_dataset'
path_crab = '/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/nuisance_summary/Crab'


dataset_standard = MapDataset.read(f'{path}/{source}/stacked.fits')
dataset_standard = dataset_standard.downsample(4)
models = Models.read(f"{path_crab}/standard_model.yml")
model_spectrum  = PowerLawSpectralModel(
    index=2.3,
    amplitude="1e-12 TeV-1 cm-2 s-1",    )
source_model = SkyModel(spatial_model = models['main source'].spatial_model ,
                       spectral_model = model_spectrum,
                       name = "Source")    
models = Models(source_model)

bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_standard.models = models

dataset_asimov = dataset_standard.copy()
dataset_asimov.counts = dataset_standard.npred()
models = Models(source_model.copy())
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_asimov.models = models

    
dataset_standard.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_standard.geoms["geom"].width[1] / dataset_standard.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_standard)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : UboUfPcs
#
#   Total counts                    : 388209
#   Total background counts         : 360331.31
#   Total excess counts             : 27877.69
#
#   Predicted counts                : 361333.07
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 1001.73
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -924522.99
#
#   Number of models                : 2
#   Number of parameters            : 11
#   Number of free parameters       : 7
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.019   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : UboUfPcs-bkg
#     Datasets names            : ['UboUfPcs']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %% [markdown]
# ## Varying the Exposure

# %%
savefig = True
picformat = 'svg'

shift = -0.085
tilt = -0.015

# %%
sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = shift, 
                        tilt = tilt,
                        rnd = False)
dataset_asimov = sys_.create_dataset()
dataset_asimov_N = sys_.create_dataset_N()

penalising_covmatrix = [[1/shift**2, 0], [0 , 1/tilt**2]]
penalising_invcovmatrix =  penalising_covmatrix
dataset_asimov_N.penalising_invcovmatrix = penalising_invcovmatrix


fit_cor = Fit(store_trace=False)

result_cor = fit_cor.run([dataset_asimov])    
result_cor = fit_cor.run([dataset_asimov_N])

# %%
dataset_asimov_N.models[-1].parameters['norm_nuisance'].frozen = True
dataset_asimov_N.models[-1].parameters['tilt_nuisance'].frozen = True

# %%
mask = dataset_asimov.mask.data[:,60,60]
ebins = dataset_asimov.counts.geom.axes[0].center[mask]
energy_bounds = (ebins[0] , ebins[-1] ) *u.TeV

# %%
true_energy = dataset_asimov.exposure.geom.axes[0].center.value
energy_bounds = (ebins[0] , ebins[-1] ) *u.TeV
fig, axs = plt.subplots(1,1, figsize = (5,3))
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Nuisance", facecolor = "red", alpha = 0.6)
dataset_asimov_N.models[0].spectral_model.plot(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", color = "green")    

dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Standard", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", color = "red")    



dataset_standard.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )

axs.set_xlabel('')
axs.legend()
plt.tight_layout()
# Out:
# index
# amplitude
# index
# amplitude
# index
# amplitude
# index
# amplitude

# %% [markdown]
# ## Compute Asimov Fluxpoints

# %%
compute_fluxpoints = 1
if compute_fluxpoints:
    energy_edges = dataset_asimov.geoms['geom'].axes[0].edges
    esti  = FluxPointsEstimator(energy_edges= energy_edges,
                               reoptimize = False)
    fluxpoints_asimov = esti.run([dataset_asimov])
    fluxpoints_asimov.write("data/6_fluxpoints_asimov.fits", overwrite = True)
else:
    fluxpoints_asimov = FluxPoints.read("data/6_fluxpoints_asimov.fits", )
# Out:
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.998584543751853 1.15925504155027
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    1.16
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.9986947027622133 0.44428204480213235
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.44
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.9989381497415819 0.2257069322456399
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.23
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.9991531546474346 0.19347589216583752
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.19
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.9993716733536961 0.19353640338205474
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.19
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.9995878745864368 0.19960224516777306
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.20
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 0.999804583525767 0.21204510522906617
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.21
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.000035304943224 0.2298703912629904
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.23
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0002491680332286 0.24807835796274283
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.25
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.000480496390681 0.27306713367612756
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.27
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.000665287225545 0.3049502344453036
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.30
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0008593236056509 0.3407757826191382
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.34
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0010446996224056 0.3852083809796912
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.39
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.001226919309912 0.4381224722986353
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.44
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0014071273538294 0.49341233160098974
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.49
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0015802095004878 0.5596319307329417
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.002   +/-    0.56
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0018546555059606 0.6456905823051783
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.002   +/-    0.65
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.002036251909474 0.771715589473754
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.002   +/-    0.77
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0
# norm 1.0 0
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                         :      0.020   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : -ihEprvD-bkg
#   Datasets names            : ['-ihEprvD']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.000   +/-    0.00
#     tilt                          :     -0.000   +/-    0.00
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 0

# %%
if compute_fluxpoints:

    esti_N  = FluxPointsEstimator(energy_edges= energy_edges,
                               reoptimize = True)
    ## modify the covariance matrix, because only one nuisance parameter here
    #penalising_covmatrix = [[1/sigma_a**2]]
    penalising_invcovmatrix =  penalising_covmatrix
    dataset_asimov_N.penalising_invcovmatrix = penalising_invcovmatrix
    with dataset_asimov_N.models.restore_status():
        dataset_asimov_N.models.parameters.freeze_all()
        dataset_asimov_N.models.parameters['norm_nuisance'].frozen = False
        dataset_asimov_N.models.parameters['tilt_nuisance'].frozen = False
        fluxpoints_asimov_N = esti_N.run(dataset_asimov_N)

    fluxpoints_asimov_N.write("data/6_fluxpoints_asimov_N.fits", overwrite = True)
else:
    fluxpoints_asimov_N = FluxPoints.read("data/6_fluxpoints_asimov_N.fits",)
# Out:
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9982102226569142 1.1621993719091308
# norm_nuisance 6.023406094971806e-06 0.08501502651826734
# tilt_nuisance 9.626436072208255e-07 0.015000036989436135
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.998   +/-    1.16
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9982232349895637 0.4527626216733926
# norm_nuisance 2.0454431308544097e-05 0.08510944046870014
# tilt_nuisance 5.9376172789026075e-06 0.015000085567479829
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.998   +/-    0.45
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9984890017288044 0.2426803521219354
# norm_nuisance -0.00011079501582938499 0.0855635424058386
# tilt_nuisance 9.981738448132075e-06 0.015000032884880153
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.998   +/-    0.24
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9987738757278364 0.21310775472636015
# norm_nuisance -0.0001250299959864342 0.08575046771161512
# tilt_nuisance 1.4187066353975633e-05 0.015000027795813992
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.21
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9990511416473266 0.21299264125859843
# norm_nuisance -5.434110609490746e-05 0.08565048451706817
# tilt_nuisance 1.7554803738538247e-05 0.01500033861382305
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.21
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9994186432377402 0.2183741089888906
# norm_nuisance -1.7053972934270513e-05 0.08549768587696878
# tilt_nuisance 1.4254406272389956e-05 0.015000740275994663
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      0.999   +/-    0.22
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 0.9997416468404895 0.22972255872376865
# norm_nuisance -1.6644902633447467e-05 0.0853339667063735
# tilt_nuisance 7.631464823642539e-06 0.015000994264314643
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.23
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0000020258288151 0.24637207752222473
# norm_nuisance -4.8063288815190666e-05 0.08522477044831983
# tilt_nuisance 1.1841020801122149e-07 0.015001139977797633
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.25
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.000151114220872 0.2634406484763113
# norm_nuisance -4.2222535721930315e-05 0.08509029328323958
# tilt_nuisance -2.425843175062359e-06 0.015000697074311845
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.26
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0003197734109108 0.2873933025542189
# norm_nuisance -3.8591770426303954e-05 0.08505114246936163
# tilt_nuisance -4.466792006642755e-06 0.01500056845162761
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.000   +/-    0.29
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.000504044007345 0.31828880144615884
# norm_nuisance -3.5292774911402746e-05 0.08505572181761895
# tilt_nuisance -5.860166156131637e-06 0.0150008441190082
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.32
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.000677886510244 0.3531791189102241
# norm_nuisance -3.114305639511472e-05 0.08505058607804954
# tilt_nuisance -6.573549932489933e-06 0.015001000045507605
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.35
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0008517264188292 0.39662239410257893
# norm_nuisance -2.7243198276252167e-05 0.08504213323978177
# tilt_nuisance -6.795379941117026e-06 0.01500106118053951
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.40
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0010284379886185 0.44857191973444027
# norm_nuisance -2.4141723012719707e-05 0.08503293983430465
# tilt_nuisance -6.713489841289071e-06 0.015001035004331961
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.45
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0012032167711842 0.5030782544723141
# norm_nuisance -2.1795857854867953e-05 0.08502428190263632
# tilt_nuisance -6.554324281007856e-06 0.015000925403707207
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.50
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0013745651633006 0.5685185428026539
# norm_nuisance -1.971528650771517e-05 0.0850171866602032
# tilt_nuisance -6.178114155232227e-06 0.015000782608031484
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.001   +/-    0.57
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.001561121277408 0.6536838571515577
# norm_nuisance -1.8095801947741075e-05 0.08501227763612777
# tilt_nuisance -5.620977409082689e-06 0.015000664913745826
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.002   +/-    0.65
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0018118558421478 0.7787061205028243
# norm_nuisance -2.6021655296434076e-05 0.08500878437857017
# tilt_nuisance -5.303321161445505e-06 0.015000568698039856
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :      1.002   +/-    0.78
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.09
#     tilt_nuisance                 :     -0.000   +/-    0.02
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2
# norm 1.0 0
# norm_nuisance -0.000346248804708373 0.0837534643454396
# tilt_nuisance -2.2982254343431222e-05 0.014966910801686861
# freeze for error
# freeze for error
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ScaleSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                          :        nan   +/-    0.00
#     lon_0                 (frozen):     83.631       deg
#     lat_0                 (frozen):     22.018       deg
#     sigma                 (frozen):      0.020       deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : dataset N-bkg
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                  (frozen):      1.000
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 2: IRFModel
#
#   Name                      : dataset N-irf
#   Datasets names            : ['dataset N']
#   Spectral model type       : PowerLawNormPenSpectralModel
#   Parameters:
#     norm_nuisance                 :     -0.000   +/-    0.08
#     tilt_nuisance                 :     -0.000   +/-    0.01
#     reference             (frozen):      1.000       TeV
#
#
# flux: len pen par: 2

# %%
def plot_shifted (ff, shift):
    return ff.energy_ref* shift, ff.e2dnde.data[:,0,0],  ff.e2dnde_err.data[:,0,0],

# %%
fig, axs = plt.subplots(1,1, figsize = (5,3))
dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Nuisance", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Standard", facecolor = "red", alpha = 0.6)

dataset_standard.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )




e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.1)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkred', fmt='o')  

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkgreen', fmt='o')  


axs.legend()
plt.tight_layout()
if savefig:
    fig.savefig(f"plots/6_fluxpoints_asimov."+ picformat)
# Out:
# index
# amplitude
# index
# amplitude
