# %%
from gammapy.datasets import MapDataset

# %%
# Licensed under a 3-clause BSD style license - see LICENSE.rst
import logging
import numpy as np
import astropy.units as u
from astropy.io import fits
from astropy.table import Table
from regions import CircleSkyRegion
import matplotlib.pyplot as plt
from gammapy.data import GTI
from gammapy.irf import EDispKernelMap, EDispMap, PSFKernel, PSFMap
from gammapy.maps import Map, MapAxis, WcsGeom
from gammapy.modeling.models import DatasetModels, FoVBackgroundModel
from gammapy.stats import (
    CashCountsStatistic,
    WStatCountsStatistic,
    cash,
    cash_sum_cython,
    get_wstat_mu_bkg,
    wstat,
)
from gammapy.utils.fits import HDULocation, LazyFitsData
from gammapy.utils.random import get_random_state
from gammapy.utils.scripts import make_name, make_path
from gammapy.utils.table import hstack_columns
from gammapy.datasets.core import Dataset
from gammapy.datasets.evaluator import MapEvaluator
from gammapy.datasets.utils import get_axes

# %%
class MapDatasetNuisanceE(MapDataset):
    stat_type = "cash"
    tag = "MapDataset"
    counts = LazyFitsData(cache=True)
    exposure = LazyFitsData(cache=True)
    edisp = LazyFitsData(cache=True)
    background = LazyFitsData(cache=True)
    psf = LazyFitsData(cache=True)
    mask_fit = LazyFitsData(cache=True)
    mask_safe = LazyFitsData(cache=True)

    _lazy_data_members = [
        "counts",
        "exposure",
        "edisp",
        "psf",
        "mask_fit",
        "mask_safe",
        "background",
    ]

    def __init__(
        self,
        models=None,
        counts=None,
        exposure=None,
        background=None,
        psf=None,
        edisp=None,
        mask_safe=None,
        mask_fit=None,
        gti=None,
        meta_table=None,
        name=None,
        N_parameters=None,
        penalty_sigma=None,
    ):
        self._name = make_name(name)
        self._evaluators = {}

        self.counts = counts
        #new
        self.N_parameters = N_parameters
        self.penalty_sigma = penalty_sigma
        self.exposure = exposure
        
            
        self.background = background
        self._background_cached = None
        self._background_parameters_cached = None

        self.mask_fit = mask_fit

        if psf and not isinstance(psf, (PSFMap, HDULocation)):
            raise ValueError(
                f"'psf' must be a 'PSFMap' or `HDULocation` object, got {type(psf)}"
            )

        self.psf = psf

        if edisp and not isinstance(edisp, (EDispMap, EDispKernelMap, HDULocation)):
            raise ValueError(
                f"'edisp' must be a 'EDispMap', `EDispKernelMap` or 'HDULocation' object, got {type(edisp)}"
            )

        self.edisp = edisp
        self.mask_safe = mask_safe
        self.gti = gti
        self.models = models
        self.meta_table = meta_table
    
    @property
    def exposure_modified(self):
        if self.N_parameters is not None:
            print("exposure after ", (self.exposure * (1+self.N_parameters[0].value)).data.max())

            return  self.exposure * (1+self.N_parameters[0].value)
        else:
            return  self.exposure 
        
    def npred_signal(self, model_name=None):
        """Model predicted signal counts.

        If a model name is passed, predicted counts from that component are returned.
        Else, the total signal counts are returned.

        Parameters
        ----------
        model_name: str
            Name of  SkyModel for which to compute the npred for.
            If none, the sum of all components (minus the background model)
            is returned

        Returns
        -------
        npred_sig: `gammapy.maps.Map`
            Map of the predicted signal counts
        """
        npred_total = Map.from_geom(self._geom, dtype=float)
        #self.update_exposure()
        evaluators = self.evaluators
        if model_name is not None:
            evaluators = {model_name: self.evaluators[model_name]}

        for evaluator in evaluators.values():
            if evaluator.needs_update or self.N_parameters is not None:
                evaluator.update(
                    self.exposure_modified,
                    self.psf,
                    self.edisp,
                    self._geom,
                    self.mask_image,
                )

            if evaluator.contributes:
                npred = evaluator.compute_npred()
                npred_total.stack(npred)

        return npred_total
  
        
    
    def npred(self):
        """Total predicted source and background counts

        Returns
        -------
        npred : `Map`
            Total predicted counts
        """
        npred_total = self.npred_signal()
        if self.background:
            npred_total += self.npred_background() * (1+self.N_parameters[0].value)
        npred_total.data[npred_total.data < 0.0] = 0
        
        return npred_total
    
    
    def stat_sum(self):
        """Total likelihood given the current model parameters."""
        counts, npred = self.counts.data.astype(float), self.npred().data
        if self.penalty_sigma:
            penalty = self.penalty_sigma * self.N_parameters.value**2
        else:
            penalty = 0
        #print('penalty', penalty)
        if self.mask is not None:
            return cash_sum_cython(counts[self.mask.data], npred[self.mask.data])  +penalty
        else:
            return cash_sum_cython(counts.ravel(), npred.ravel()) +penalty

# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-11-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-11-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset ,Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

sys.path.append(
    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
)
#from my_dataset_maps_20_e import MapDatasetNuisanceE
from  my_fit_20 import Fit
import my_dataset_core_20_e , my_fit_20_e

# %% [markdown]
# ## Read dataset

# %%
source = 'Crab'
path = '/home/vault/caph/mppi062h/repositories/HESS_3Dbkg_syserror/2-error_in_dataset'
path_crab = '/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/nuisance_summary/Crab'


dataset_load = MapDataset.read(f'{path}/{source}/stacked.fits')
dataset_load = dataset_load.downsample(4)
models = Models.read(f"{path_crab}/standard_model.yml")
model_spectrum  = PowerLawSpectralModel(
    index=2.3,
    amplitude="1e-12 TeV-1 cm-2 s-1",    )
source_model = SkyModel(spatial_model = models['main source'].spatial_model ,
                       spectral_model = model_spectrum,
                       name = "Source")    
models = Models(source_model)

bkg_model = FoVBackgroundModel(dataset_name=dataset_load.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_load.models = models

dataset_asimov = dataset_load.copy()
dataset_asimov.counts = dataset_load.npred()
models = Models(source_model.copy())
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_asimov.models = models

    
dataset_load.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_load.geoms["geom"].width[1] / dataset_load.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_load)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : bdjgha6c
#
#   Total counts                    : 388209
#   Total background counts         : 360331.31
#   Total excess counts             : 27877.69
#
#   Predicted counts                : 361333.07
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 1001.73
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -924522.99
#
#   Number of models                : 2
#   Number of parameters            : 11
#   Number of free parameters       : 7
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.019   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : bdjgha6c-bkg
#     Datasets names            : ['bdjgha6c']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %%
def create_dataset(factor):
    dataset = dataset_asimov.copy()
    exposure = dataset.exposure.copy()
    exposure.data *= (1+factor)
    background = dataset.background.copy()
    background.data *= (1+factor)
    
    
    dataset.exposure = exposure
    dataset.background = background

    counts_data = np.random.poisson(dataset_asimov.counts.data)
    dataset.counts.data = counts_data
    
    models = Models.read(f"{path_crab}/standard_model.yml").copy()
    model_spectrum  = PowerLawSpectralModel(
        index=2.3,
        amplitude="1e-12 TeV-1 cm-2 s-1",    )
    source_model = SkyModel(spatial_model = models['main source'].spatial_model ,
                           spectral_model = model_spectrum,
                           name = "Source")    
    models = Models(source_model)
    bkg_model = FoVBackgroundModel(dataset_name=dataset.name)
    bkg_model.parameters['tilt'].frozen  = False

    models.append(bkg_model)
    dataset.models = models
    return dataset

def create_dataset_N(factor, simga):
    dataset_ = create_dataset(factor)
    
    N_parameter = Parameter(name = "effarea", value = 0)
    N_parameters = Parameters([N_parameter])
    dataset_N = MapDatasetNuisanceE (
            counts=dataset_.counts.copy(),
            exposure=dataset_.exposure.copy(),
            background=dataset_.background.copy(),
            psf=dataset_.psf.copy(),
            edisp=dataset_.edisp.copy(),
            mask_safe=dataset_.mask_safe.copy(),
            gti=dataset_.gti.copy(),
            name='dataset N',
            N_parameters=N_parameters,
            penalty_sigma= simga)
    models = Models(source_model.copy(name = "Source"))
    bkg_model = FoVBackgroundModel(dataset_name=dataset_N.name)
    bkg_model.parameters['tilt'].frozen  = False
    models.append(bkg_model)
    dataset_N.models = models
    return dataset_N

# %%
factor = 0
dataset_standard = create_dataset(factor)

my_fit_standard = Fit()
result_standard = my_fit_standard.run([dataset_standard])

# %%
sigma = 0.5
dataset_N = create_dataset_N(factor,sigma )
dataset_Ns = my_dataset_core_20_e.Datasets([dataset_N])

my_fit = my_fit_20_e.Fit()
result = my_fit.run([dataset_N])

# %%
'''energy_bounds = (0.1,100 ) * u.TeV

npred = dataset_standard.npred_signal().data.sum(axis = 2).sum(axis= 1)
npred_neg = dataset_N.npred_signal().data.sum(axis = 2).sum(axis= 1)


plt.plot( npred, label = "Model ")
plt.plot( npred_neg, label = f"Model  {N_parameters[0].value  *100} % sys")

         
plt.loglog()
plt.legend()
plt.xlabel("Energy [TeV]")
plt.ylabel("Predicted Counts")'''

# %%
'''energy_bounds = (0.1,100 ) * u.TeV

npred = dataset_standard.npred().data.sum(axis = 2).sum(axis= 1)
npred_neg = dataset_N.npred().data.sum(axis = 2).sum(axis= 1)
print(dataset_N.npred().data.max())

plt.plot( npred, label = "Model ")
plt.plot( npred_neg, label = f"Model  {N_parameters[0].value  *100} % sys")

         
plt.loglog()
plt.legend()
plt.xlabel("Energy [TeV]")
plt.ylabel("Predicted Counts")'''

# %% [markdown]
# ## Fitting

# %%
i = 0
for p_as, p_N  in zip (dataset_asimov.models.parameters.free_parameters, dataset_N.models.parameters.free_parameters):
    i +=1 
    #print(p_as.value)
    if p_as.value >0:
        print( p_N.value/ p_as.value)
        plt.errorbar(i, p_N.value/ p_as.value,
                     yerr = p_N.error, fmt='x' , label = p_as.name,
                    color = f'C{i}')

        
i=0    
for p_as, p_N  in zip (dataset_asimov.models.parameters.free_parameters,
                       dataset_standard.models.parameters.free_parameters):
    i +=1
    if p_as.value >0:
        print( p_N.value/ p_as.value)
        plt.errorbar(i + 0.2, p_N.value/ p_as.value,
                     yerr = p_N.error, fmt='o' , label = '', 
                    color = f'C{i}')
    
    
plt.plot(0, dataset_N.N_parameters.value, 'x' , label = "Nuisance")
plt.plot(0.1, factor, 'x' , label = "Input Nuisance")
    
plt.legend()

# %% [markdown]
# ## Mulitple Cases

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
N = 1
factors = np.random.normal(mu, sigma, N)
factors
count, bins, ignored = plt.hist(factors, 30, density=True)

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *

               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),

         linewidth=2, color='r')
plt.xlabel("Systematic")
# Out:
# Text(0.5, 0, 'Systematic')

# %%
datasets = []
datasets_N = []

for i, factor in enumerate(factors):
    print(i, factor)
    dataset = create_dataset(factor)
    datasets.append(dataset)
    #result = estimator.run(dataset)
    #result["sqrt_ts"].plot_grid(cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5,);
    dataset_N = create_dataset_N(factor,sigma )
    datasets_N.append(dataset_N)
# Out:
# 0 -0.06254783588863731

# %%
# %%time
for i, factor in enumerate(factors):
    print(i, factor)
    fit = Fit(store_trace=False)
    result = fit.run([datasets[i]])
# Out:
# 0 -0.06474808167659801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:4, in <module>
#
# File ~/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters/my_fit_20.py:163, in Fit.run(self, datasets)
#     150 def run(self, datasets):
#     151     """Run all fitting steps.
#     152
#     153     Parameters
#    (...)
#     161         Fit result
#     162     """
# --> 163     optimize_result = self.optimize(datasets=datasets)
#     165     if self.backend not in registry.register["covariance"]:
#     166         log.warning("No covariance estimate - not supported by this backend.")
#
# File ~/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters/my_fit_20.py:207, in Fit.optimize(self, datasets)
#     203 compute = registry.get("optimize", backend)
#     204 # TODO: change this calling interface!
#     205 # probably should pass a fit statistic, which has a model, which has parameters
#     206 # and return something simpler, not a tuple of three things
# --> 207 factors, info, optimizer = compute(
#     208     parameters=parameters,
#     209     function=datasets.stat_sum,
#     210     store_trace=self.store_trace,
#     211     **kwargs,
#     212 )
#     214 if backend == "minuit":
#     215     self._minuit = optimizer
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/modeling/iminuit.py:79, in optimize_iminuit(parameters, function, store_trace, **kwargs)
#      73 migrad_opts = kwargs.pop("migrad_opts", {})
#      75 minuit, minuit_func = setup_iminuit(
#      76     parameters=parameters, function=function, store_trace=store_trace, **kwargs
#      77 )
# ---> 79 minuit.migrad(**migrad_opts)
#      81 factors = minuit.values
#      82 info = {
#      83     "success": minuit.valid,
#      84     "nfev": minuit.nfcn,
#      85     "message": _get_message(minuit, parameters),
#      86     "trace": minuit_func.trace,
#      87 }
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/iminuit/minuit.py:694, in Minuit.migrad(self, ncall, iterate)
#     692 if self._precision is not None:
#     693     migrad.precision = self._precision
# --> 694 fm = migrad(ncall, self._tolerance)
#     695 if fm.is_valid or fm.has_reached_call_limit:
#     696     break
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/modeling/iminuit.py:25, in MinuitLikelihood.fcn(self, *factors)
#      22 def fcn(self, *factors):
#      23     self.parameters.set_parameter_factors(factors)
# ---> 25     total_stat = self.function()
#      27     if self.store_trace:
#      28         self.store_trace_iteration(total_stat)
#
# File ~/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters/my_dataset_core_20.py:250, in Datasets.stat_sum(self)
#     248 # TODO: add parallel evaluation of likelihoods
#     249 for dataset in self:
# --> 250     stat_sum += dataset.stat_sum()
#     251 return stat_sum
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/map.py:1084, in MapDataset.stat_sum(self)
#    1082 def stat_sum(self):
#    1083     """Total likelihood given the current model parameters."""
# -> 1084     counts, npred = self.counts.data.astype(float), self.npred().data
#    1086     if self.mask is not None:
#    1087         return cash_sum_cython(counts[self.mask.data], npred[self.mask.data])
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/map.py:434, in MapDataset.npred(self)
#     426 def npred(self):
#     427     """Total predicted source and background counts
#     428
#     429     Returns
#    (...)
#     432         Total predicted counts
#     433     """
# --> 434     npred_total = self.npred_signal()
#     436     if self.background:
#     437         npred_total += self.npred_background()
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/map.py:511, in MapDataset.npred_signal(self, model_name)
#     502         evaluator.update(
#     503             self.exposure,
#     504             self.psf,
#    (...)
#     507             self.mask_image,
#     508         )
#     510     if evaluator.contributes:
# --> 511         npred = evaluator.compute_npred()
#     512         npred_total.stack(npred)
#     514 return npred_total
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/evaluator.py:385, in MapEvaluator.compute_npred(self)
#     382 if self.parameters_changed or not self.use_cache:
#     383     del self._compute_npred
# --> 385 return self._compute_npred
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/astropy/utils/decorators.py:785, in lazyproperty.__get__(self, obj, owner)
#     783         val = obj_dict.get(self._key, _NotFound)
#     784         if val is _NotFound:
# --> 785             val = self.fget(obj)
#     786             obj_dict[self._key] = val
#     787 return val
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/evaluator.py:361, in MapEvaluator._compute_npred(self)
#     359 if not self.parameter_norm_only_changed:
#     360     for method in self.methods_sequence:
# --> 361         values = method(self._computation_cache)
#     362         self._computation_cache = values
#     363     npred = self._computation_cache
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/datasets/evaluator.py:351, in MapEvaluator.apply_edisp(self, npred)
#     338 def apply_edisp(self, npred):
#     339     """Convolve map data with energy dispersion.
#     340
#     341     Parameters
#    (...)
#     349         Predicted counts in reco energy bins
#     350     """
# --> 351     return npred.apply_edisp(self.edisp)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/maps/core.py:1404, in Map.apply_edisp(self, edisp)
#    1402     data = np.dot(data, edisp.pdf_matrix)
#    1403     data = np.rollaxis(data, -1, loc)
# -> 1404     energy_axis = edisp.axes["energy"].copy(name="energy")
#    1405 else:
#    1406     data = self.data
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/maps/axes.py:904, in MapAxis.copy(self, **kwargs)
#     891 def copy(self, **kwargs):
#     892     """Copy `MapAxis` instance and overwrite given attributes.
#     893
#     894     Parameters
#    (...)
#     902         Copied map axis.
#     903     """
# --> 904     return self._init_copy(**kwargs)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/site-packages/gammapy/maps/axes.py:882, in MapAxis._init_copy(self, **kwargs)
#     880 def _init_copy(self, **kwargs):
#     881     """Init map axis instance by copying missing init arguments from self."""
# --> 882     argnames = inspect.getfullargspec(self.__init__).args
#     883     argnames.remove("self")
#     885     for arg in argnames:
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/inspect.py:1162, in getfullargspec(func)
#    1130 """Get the names and default values of a callable object's parameters.
#    1131
#    1132 A tuple of seven things is returned:
#    (...)
#    1143   - wrapper chains defined by __wrapped__ *not* unwrapped automatically
#    1144 """
#    1145 try:
#    1146     # Re: `skip_bound_arg=False`
#    1147     #
#    (...)
#    1159     # getfullargspec() historically ignored __wrapped__ attributes,
#    1160     # so we ensure that remains the case in 3.3+
# -> 1162     sig = _signature_from_callable(func,
#    1163                                    follow_wrapper_chains=False,
#    1164                                    skip_bound_arg=False,
#    1165                                    sigcls=Signature)
#    1166 except Exception as ex:
#    1167     # Most of the times 'signature' will raise ValueError.
#    1168     # But, it can also raise AttributeError, and, maybe something
#    1169     # else. So to be fully backwards compatible, we catch all
#    1170     # possible exceptions here, and reraise a TypeError.
#    1171     raise TypeError('unsupported callable') from ex
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/inspect.py:2266, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2261     raise TypeError('{!r} is not a callable object'.format(obj))
#    2263 if isinstance(obj, types.MethodType):
#    2264     # In this case we skip the first parameter of the underlying
#    2265     # function (usually `self` or `cls`).
# -> 2266     sig = _get_signature_of(obj.__func__)
#    2268     if skip_bound_arg:
#    2269         return _signature_bound_method(sig)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/inspect.py:2325, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2320             return sig.replace(parameters=new_params)
#    2322 if isfunction(obj) or _signature_is_functionlike(obj):
#    2323     # If it's a pure Python function, or an object that is duck type
#    2324     # of a Python function (Cython functions, for instance), then:
# -> 2325     return _signature_from_function(sigcls, obj,
#    2326                                     skip_bound_arg=skip_bound_arg)
#    2328 if _signature_is_builtin(obj):
#    2329     return _signature_from_builtin(sigcls, obj,
#    2330                                    skip_bound_arg=skip_bound_arg)
#
# File ~/anaconda3/envs/gammapy-1.0/lib/python3.9/inspect.py:2202, in _signature_from_function(cls, func, skip_bound_arg)
#    2199         posonly_left -= 1
#    2201 # ... w/ defaults.
# -> 2202 for offset, name in enumerate(positional[non_default_count:]):
#    2203     kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2204     annotation = annotations.get(name, _empty)
#
# KeyboardInterrupt:

# %%
# %%time
for i, factor in enumerate(factors):
    fit_N = Fit(store_trace=False)
    result_N = fit_N.run([datasets_N[i]])
    print(i, factor, datasets_N[i].N_parameters.value)

# %%
npred_signal = datasets_N[i].npred_signal()
print(npred_signal.data.max())
datasets_N[i].N_parameters[0].value = 1
npred_signal = datasets_N[i].npred_signal()
print(npred_signal.data.max())
# Out:
# exposure after  WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat', 'energy_true']
# 	shape : (150, 150, 24)
# 	ndim  : 3
# 	unit  : m2 s
# 	dtype : float32
#
# 17.20383480831265
# exposure after  WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat', 'energy_true']
# 	shape : (150, 150, 24)
# 	ndim  : 3
# 	unit  : m2 s
# 	dtype : float32
#
# 34.4076696166253

# %%
print(gammapy)

# %%
dataset_asimov.models[0].parameters.to_table()

# %%
datasets_N[0].N_parameters.to_table()

# %%
fig, ax= plt.subplots(2,1, figsize = (10,5))
amplitudes = []
for i, d in enumerate(datasets):
    m = d.models['Source']
    value = m.parameters['amplitude'].value 
    value_input = dataset_asimov.models[0].parameters['amplitude'].value 
    print(value/value_input)
    amplitudes.append(value/value_input)
    error = m.parameters['amplitude'].error
    ax[0].errorbar(x= 1+ factors[i] , y =  value / value_input, yerr = error /value_input, fmt = 'o')
    ax[0].plot([1+factors.min(), 1+factors.max()], [1,1])
    asimov_ampli = dataset_asimov.models[0].parameters['amplitude'].value
    asimov_ampli_error = dataset_asimov.models[0].parameters['amplitude'].error
    
ax[0].fill_between([factors.min(), factors.max()],
                       asimov_ampli- asimov_ampli_error, asimov_ampli +asimov_ampli_error,
                        label = "Best Fit + error (Asimov)")
ax[0].set_ylim(0.5,1.5)
ax[0].set_xlim(0.75,1.25)

norms = []
for i,  d in enumerate(datasets):
    value = d.background_model.parameters['norm'].value 
    norms.append(value)
    error = d.background_model.parameters['norm'].error
    ax[1].errorbar(x=  1+factors[i] , y =  value, yerr = error, fmt = 'o')
    ax[1].plot([1+factors.min(), 1+factors.max()], [1,1])
    asimov_norm = dataset_asimov.background_model.parameters['norm'].value
    asimov_norm_error = dataset_asimov.background_model.parameters['norm'].error
    
ax[1].fill_between([1+factors.min(), 1+factors.max()],
                       asimov_norm- asimov_norm_error, asimov_norm +asimov_norm_error,
                      label = "Best Fit + error (Asimov)")
ax[1].set_xlim(0.75,1.25)
    
ax[0].set_ylabel("Best Fit Amplitude")       
ax[1].set_xlabel("Systematic []")       
ax[1].set_ylabel("Best Fit BG Norm")    
ax[0].legend(); ax[1].legend();

# %%
fig, ax= plt.subplots(3,1, figsize = (10,7.5))
amplitudes_N = []
for i, d in enumerate(datasets_N):
    m = d.models[0]
    value = m.parameters['amplitude'].value 
    value_input = dataset_asimov.models[0].parameters['amplitude'].value 
    amplitudes_N.append(value/value_input)
    error = m.parameters['amplitude'].error
    ax[0].errorbar(x=  1+factors[i] , y =  value / value_input, yerr = error /value_input, fmt = 'o')
    ax[0].plot([1+factors.min(), 1+factors.max()], [1,1])
    asimov_ampli = dataset_asimov.models[0].parameters['amplitude'].value
    asimov_ampli_error = dataset_asimov.models[0].parameters['amplitude'].error
    
ax[0].fill_between([factors.min(), factors.max()],
                       asimov_ampli- asimov_ampli_error, asimov_ampli +asimov_ampli_error,
                        label = "Best Fit + error (Asimov)")
ax[0].set_ylim(0.5,1.5)
ax[0].set_xlim(0.75,1.25)

norms_N = []
for i,  d in enumerate(datasets_N):
    value = d.background_model.parameters['norm'].value 
    norms_N.append(value)
    error = d.background_model.parameters['norm'].error
    ax[1].errorbar(x= 1+ factors[i] , y =  value, yerr = error, fmt = 'o')
    ax[1].plot([1+factors.min(), 1+factors.max()], [1,1])
    asimov_norm = dataset_asimov.background_model.parameters['norm'].value
    asimov_norm_error = dataset_asimov.background_model.parameters['norm'].error
    
ax[1].fill_between([factors.min(), factors.max()],
                       asimov_norm- asimov_norm_error, asimov_norm +asimov_norm_error,
                      label = "Best Fit + error (Asimov)")
ax[1].set_xlim(0.75,1.25)
    
ax[0].set_ylabel("Best Fit Amplitude")       
ax[1].set_xlabel("Systematic []")       
ax[1].set_ylabel("Best Fit BG Norm")    
ax[0].legend(); ax[1].legend(); 


N_parameters = []
for i,  d in enumerate(datasets_N):
    value = d.N_parameters.value 
    print(value)
    N_parameters.append(value)
    ax[2].errorbar(x= 1+ factors[i] , y = 1+ value,  fmt = 'o')
    ax[2].plot([1+factors.min(), 1+factors.max()], [1,1])
    asimov_norm = dataset_asimov.background_model.parameters['norm'].value
    asimov_norm_error = dataset_asimov.background_model.parameters['norm'].error

# %%
fig, ax= plt.subplots(1,3, figsize = (15,5))
nbins = 25

ax[0].hist(amplitudes, nbins, label = f'{np.mean(amplitudes):.2} pm {np.std(amplitudes):.2}')
ax[0].set_title('Best fit amplitudes')
ax[0].set_xlabel('Value/ Input')
ax[0].errorbar(x=asimov_ampli/1e-12, y = 3, xerr =asimov_ampli_error/1e-12, fmt = 'o' , label = "Asmiov")
ax[0].legend()

ax[1].hist(norms, nbins, label = f'{np.mean(norms):.2} pm {np.std(norms):.2}')
ax[1].set_title('Best fit BG norms')
ax[1].set_xlabel('Value/ Input')
ax[1].errorbar(x=asimov_norm, y = 3, xerr =asimov_norm_error, fmt = 'o', label = "Asimov" )
ax[1].legend()


ax[0].hist(amplitudes_N, nbins, label = f'Nui: {np.mean(amplitudes_N):.2} pm {np.std(amplitudes_N):.2}')
ax[0].set_title('Best fit amplitudes')
ax[0].set_xlabel('Value/ Input')
ax[0].legend()

ax[1].hist(norms_N, nbins, label = f'Nui: {np.mean(norms_N):.2} pm {np.std(norms_N):.2}')
ax[1].set_title('Best fit BG norms')
ax[1].set_xlabel('Value/ Input')
ax[1].legend()



count, bins, ignored = ax[2].hist(factors, nbins, density=True, color = 'darkred', 
                                 label = f'Input: {np.mean(factors):.2} pm {np.std(factors):.2}')
ax[2].hist(np.array(N_parameters).flatten(), nbins,density=1,
           label = f'Nui: {np.mean(N_parameters):.2} pm {np.std(N_parameters):.2}')

ax[2].plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
ax[2].set_xlabel("Drawn distribution")
ax[2].set_xlabel("Systematic")
ax[2].legend()
