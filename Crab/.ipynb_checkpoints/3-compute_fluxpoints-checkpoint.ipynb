# %% [markdown]
# # Import the Dataset
#
# In this notebook a 3D analysis of the -- is demonstated. In addition to the usuall model parameters so called 'nuisance parameters' are fitted which account for any systematical uncertainties. These sysetmatical uncertainties are assumed to be due a missmodelling of the hardronic background.
#
# The nuisance parameters are correlated so they can only eliminate the systemtic uncertainties but not the uncorrelated statistical uncertainicies.
#
# Here the Fluxpoints of the source are fitted. Hereby, the MapDatasetNuisance is sliced into certain energybins and within this energybin only the source normalisation and the nusiance parameters of this energybin are fitted. The normalisation of the bg and all the other model parameters are frozen.
#
# The dataset itself was set-up and fitted in the whole energyrange in the notebook `Tutorial_Nuisance_Parameter_Fitting`.

# %%
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset #, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
)
from regions import CircleSkyRegion

import sys
import yaml
sys.path.append(
    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
)
from my_dataset_maps_19 import MapDatasetNuisance
from  my_fit_19 import Fit

# %%
source  = "Crab"
dataset_path = f"/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/2-source_dataset/{source}/{source}_fullsys.fits"
dataset_standard = MapDataset.read(dataset_path)
dataset_standard = dataset_standard.cutout(
    position=dataset_standard.geoms["geom"].center_skydir, width=4 * u.deg
)

# %% [markdown]
# ## Standard Analysis
# Setting up the model

# %%
if source == "Crab":

    # here the dataset with the fine binning is saved
    #dataset_standard = MapDataset.read(f'{path}/{source}/stacked.fits')
    # This is for now the binning of 0.08 deg
    dataset_standard = MapDataset.read(f'{source}/stacked.fits')

    models = Models.read(f"{source}/standard_model.yml")
    
    with open(f"{source}/nui_bgmodel.yml", "r") as ymlfile:
        best_fit_bgmodel = yaml.load(ymlfile, Loader=yaml.FullLoader)
    bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
    bkg_model.parameters['norm'].value = best_fit_bgmodel['spectral']['parameters'][0]['value']
    bkg_model.parameters['tilt'].value = best_fit_bgmodel['spectral']['parameters'][1]['value']
    bkg_model.parameters['norm'].error = best_fit_bgmodel['spectral']['parameters'][0]['error']
    bkg_model.parameters['tilt'].error = best_fit_bgmodel['spectral']['parameters'][1]['error']
    models.append(bkg_model)
    dataset_standard.models = models



if source == "NGC253":
    spatial_model_NGC253 = PointSpatialModel(
        lon_0="11.8875 deg", lat_0="-25.2883 deg", frame="icrs"
    )
    spectral_model_NGC253 = PowerLawSpectralModel(
        index=2.39, amplitude="1.34e-13 cm-2 s-1 TeV-1", reference="1 TeV"
    )
    modelNGC253 = SkyModel(
        spatial_model=spatial_model_NGC253,
        spectral_model=spectral_model_NGC253,
        name="NGC253",
    )
    models_NGC253 = Models([modelNGC253])

    bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
    bkg_model.parameters["tilt"].frozen = False
    # models_NGC253.parameters['lon_0'].frozen = True
    # models_NGC253.parameters['lat_0'].frozen = True
    models_NGC253.append(bkg_model)
    dataset_standard.models = models_NGC253
dataset_standard.counts.sum_over_axes().plot(add_cbar=1)
print(
    "spatial binsize = ",
    dataset_standard.geoms["geom"].width[1]
    / dataset_standard.geoms["geom"].data_shape[1],
)
# Out:
# spatial binsize =  [0.08] deg

# %% [markdown]
# Performing the standard fit.

# %%
fit_standarad = Fit(store_trace=False)
result_standarad = fit_standarad.run([dataset_standard])

# %% [markdown]
# The first two energybins of the dataset are not fitted well ...

# %%
res_standard = (
    dataset_standard.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(6, 8)))
    .smooth(0.1 * u.deg)
)
vmax = np.nanmax(np.abs(res_standard.data))
res_standard.plot_grid(add_cbar=1, vmax=vmax, vmin=-vmax, cmap="coolwarm");
# Out:
# /home/hpc/caph/mppi045h/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %% [markdown]
# ## Import the MapDatasetNuisance

# %%
added = '_008_624'
ebins = range(6,20)

path = '/home/vault/caph/mppi062h/repositories/HESS_3Dbkg_syserror/2-error_in_dataset'
pathsource = f"{source}/"
dataset_N = MapDatasetNuisance.read(f"{path}/{pathsource}nui_dataset{added}.fits")
with open(f'{pathsource}nui_par{added}.yml', "r") as ymlfile:
    nui_par = yaml.load(ymlfile, Loader=yaml.FullLoader)
dataset_N.N_parameters = Parameters.from_dict(nui_par )
with open(f'{pathsource}nui_model{added}.yml', "r") as ymlfile:
    best_fit_model = yaml.load(ymlfile, Loader=yaml.FullLoader)
with open(f'{pathsource}nui_bgmodel{added}.yml', "r") as ymlfile:
    best_fit_bgmodel = yaml.load(ymlfile, Loader=yaml.FullLoader)
bkg_model = FoVBackgroundModel(dataset_name=dataset_N.name)
bkg_model.parameters['norm'].value = best_fit_bgmodel['spectral']['parameters'][0]['value']
bkg_model.parameters['tilt'].value = best_fit_bgmodel['spectral']['parameters'][1]['value']
bkg_model.parameters['norm'].error = best_fit_bgmodel['spectral']['parameters'][0]['error']
bkg_model.parameters['tilt'].error = best_fit_bgmodel['spectral']['parameters'][1]['error']
models = Models.from_dict(best_fit_model )
models.append(bkg_model)
dataset_N.models =models
dataset_N.geoms['geom']
# Out:
# WcsGeom
#
# 	axes       : ['lon', 'lat', 'energy']
# 	shape      : (150, 150, 24)
# 	ndim       : 3
# 	frame      : icrs
# 	projection : CAR
# 	center     : 83.6 deg, 22.0 deg
# 	width      : 12.0 deg x 12.0 deg
# 	wcs ref    : 83.6 deg, 22.0 deg

# %%
'''# reading the MapDatasetNuisance
added = '_008_624'
ebins = range(6,20)

path = '/home/vault/caph/mppi062h/repositories/HESS_3Dbkg_syserror/2-error_in_dataset'
pathsource = f"{source}/"
dataset_N = MapDatasetNuisance.read(f"{path}/{pathsource}nui_dataset{added}.fits")

#outputfile = 'output/Tutorial_output'
#dataset_N = MapDatasetNuisance.read(outputfile+'/nui_dataset.fits')
with open(outputfile+'/nui_model.yml', 'r') as file:
    nui_model = yaml.full_load(file)
models = Models.from_dict(nui_model)
# gets somehow read into as an int which causes problems when printing with precison
models.parameters['reference'].error = float(models.parameters['reference'].error)

print(models)

with open(outputfile+'/nui_bgmodel.yml', 'r') as file:
    nui_bg_model = yaml.full_load(file)

bkg_model = FoVBackgroundModel(dataset_name = dataset_N.name, )

models.append(bkg_model)
dataset_N.models =models
dataset_N.background_model.parameters['tilt'].value = nui_bg_model['spectral']['parameters'][1]['value']
dataset_N.background_model.parameters['norm'].value = nui_bg_model['spectral']['parameters'][0]['value']
dataset_N.background_model.parameters['tilt'].frozen = False
dataset_N.background_model.parameters['tilt'].error = nui_bg_model['spectral']['parameters'][1]['error']
dataset_N.background_model.parameters['norm'].error = nui_bg_model['spectral']['parameters'][0]['error']
dataset_N.background_model.parameters['reference'].error = float(0.0)

with open(outputfile+'/nui_par.yml', ) as file:
    nui_par = yaml.full_load(file)
N_parameters = Parameters.from_dict(nui_par)
dataset_N.N_parameters =N_parameters
print("max nui par:", N_parameters.value.max())
print(dataset_N)'''
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : NGC253
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :      2.564   +/-    0.02
#     amplitude               :   1.50e-13   +/- 2.7e-15 1 / (cm2 s TeV)
#     reference    (frozen)   :      1.000       TeV
#     lon_0                   :     11.891   +/-    0.19 deg
#     lat_0                   :    -25.306   +/-    0.17 deg
#
# Component 1: FoVBackgroundModel
#
#   Name                      : a9CLKX8Y-bkg
#   Datasets names            : ['a9CLKX8Y']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :      0.968   +/-    0.02
#     tilt         (frozen)   :     -0.023
#     reference    (frozen)   :      1.000       TeV
#
#
# max nui par: 0.12237805311985216
# MapDatasetNuisance
# ------------------
#
#   Name                            : GQcRkpwP
#
#   Total counts                    : 351832
#   Total background counts         : 367072.25
#   Total excess counts             : -15240.25
#
#   Predicted counts                : 351834.37
#   Predicted background counts     : 351508.57
#   Predicted excess counts         : 325.80
#
#   Exposure min                    : 3.07e+05 m2 s
#   Exposure max                    : 1.28e+11 m2 s
#
#   Number of total bins            : 60000
#   Number of fit bins              : 50000
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -1488569.09
#
#   Number of models                : 2
#   Number of parameters            : 8
#   Number of free parameters       : 6
#
#   Component 0: SkyModel
#
#     Name                      : NGC253
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                   :      2.564   +/-    0.02
#       amplitude               :   1.50e-13   +/- 2.7e-15 1 / (cm2 s TeV)
#       reference    (frozen)   :      1.000       TeV
#       lon_0                   :     11.891   +/-    0.19 deg
#       lat_0                   :    -25.306   +/-    0.17 deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : GQcRkpwP-bkg
#     Datasets names            : ['GQcRkpwP']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                    :      0.968   +/-    0.02
#       tilt                    :     -0.023   +/-    0.03
#       reference    (frozen)   :      1.000       TeV
#
#     Number of Nuisance parameters   : 50
#   Number of free Nuisance parameters: 50

# %% [markdown]
# ## Comparison to Standard Analysis

# %% [markdown]
# The spectral residual points show again how especially the first two energybins are not fitted well

# %%
kwargs_spectral = dict()
kwargs_spectral["region"] = CircleSkyRegion(
    dataset_standard.geoms["geom"].center_skydir, radius=3 * u.deg
)
kwargs_spectral["method"] = "diff/sqrt(model)"
dataset_standard.plot_residuals(kwargs_spectral=kwargs_spectral);
# Out:
# /home/hpc/caph/mppi045h/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %% [markdown]
# After including the nuisance parameters the model description is much better in the first two energy bins. This indicates that the method worked and has improved out analysis.

# %%
res_N = (
    dataset_N.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(6, 8)))
    .smooth(0.1 * u.deg)
)
vmax = np.nanmax(np.abs(res_standard.data))
res_N.plot_grid(add_cbar=1, vmax=vmax, vmin=-vmax, cmap="coolwarm");
# Out:
# /home/hpc/caph/mppi045h/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %%
dataset_N.plot_residuals(kwargs_spectral=kwargs_spectral);
# Out:
# /home/hpc/caph/mppi045h/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %% [markdown]
# Her a comparison of the distribution of the significance maps in the first two energy bins is shown. With the nuisance parameters the mean of the distribution $\mu$ got closer to zero and the standard deviation $\sigma$ is closer to the expected $1$.

# %%
i_start, i_end = 6, 8
res_standard = (
    dataset_standard.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(i_start, i_end)))
    .data.flatten()
)
res_N = (
    dataset_N.residuals("diff/sqrt(model)")
    .slice_by_idx(dict(energy=slice(i_start, i_end)))
    .data.flatten()
)

_, bins, _ = plt.hist(
    res_standard,
    bins=50,
    alpha=0.4,
    label="Standard: \n$\mu$ = {:.3} \n$\sigma$ = {:.3}".format(
        np.nanmean(res_standard), np.nanstd(res_standard)
    ),
)
plt.hist(
    res_N,
    bins=bins,
    alpha=0.4,
    label="Nuisance: \n$\mu$ = {:.3} \n$\sigma$ = {:.3}".format(
        np.nanmean(res_N), np.nanstd(res_N)
    ),
)
plt.yscale("log")
plt.legend()
plt.xlabel("Significance")
plt.ylabel("Amount");

# %% [markdown]
# Due to the larger parameter space, the error bars of the parameters with the nuisance parameters are larger than from the standard analysis.

# %%
dataset_N.models.parameters.to_table()
# Out:
# <Table length=12>
#   type      name     value         unit      ...    min        max    frozen link
#   str8      str9    float64       str14      ...  float64    float64   bool  str1
# -------- --------- ---------- -------------- ... ---------- --------- ------ ----
# spectral amplitude 3.7032e-11 cm-2 s-1 TeV-1 ...        nan       nan  False
# spectral reference 1.0000e+00            TeV ...        nan       nan   True
# spectral     alpha 2.5191e+00                ...        nan       nan  False
# spectral      beta 1.0238e-01                ...        nan       nan  False
#  spatial     lon_0 8.3631e+01            deg ...        nan       nan  False
#  spatial     lat_0 2.2018e+01            deg ... -9.000e+01 9.000e+01  False
#  spatial     sigma 1.9247e-02            deg ...  0.000e+00       nan  False
#  spatial         e 0.0000e+00                ...  0.000e+00 1.000e+00   True
#  spatial       phi 0.0000e+00            deg ...        nan       nan   True
# spectral      norm 1.0109e+00                ...        nan       nan  False
# spectral      tilt 8.3147e-03                ...        nan       nan   True
# spectral reference 1.0000e+00            TeV ...        nan       nan   True

# %%
print(" with nuisance")
print("(without nuisance)")
for p_N, p_stand in zip(dataset_N.models.parameters,dataset_standard.models.parameters ):
    print()
    print('='*50)
    print(p_N.name, p_stand.name)
    print('-'*50)
    print(' {:.3} pm {:.3}'.format(p_N.value, float((p_N.error) )    ))
    print('({:.3} pm {:.3})'.format(p_stand.value, float((p_stand.error) )))
# Out:
#  with nuisance
# (without nuisance)
#
# ==================================================
# amplitude amplitude
# --------------------------------------------------
#  3.7e-11 pm 4.7e-13
# (3.7e-11 pm 2.83e-13)
#
# ==================================================
# reference reference
# --------------------------------------------------
#  1.0 pm 0.0
# (1.0 pm 0.0)
#
# ==================================================
# alpha alpha
# --------------------------------------------------
#  2.52 pm 0.0469
# (2.51 pm 0.0184)
#
# ==================================================
# beta beta
# --------------------------------------------------
#  0.102 pm 0.00472
# (0.103 pm 0.00911)
#
# ==================================================
# lon_0 lon_0
# --------------------------------------------------
#  83.6 pm 0.472
# (83.6 pm 0.000401)
#
# ==================================================
# lat_0 lat_0
# --------------------------------------------------
#  22.0 pm 0.472
# (22.0 pm 0.000442)
#
# ==================================================
# sigma sigma
# --------------------------------------------------
#  0.0192 pm 0.000471
# (0.0192 pm 0.00164)
#
# ==================================================
# e e
# --------------------------------------------------
#  0.0 pm 0.0
# (0.0 pm 0.0)
#
# ==================================================
# phi phi
# --------------------------------------------------
#  0.0 pm 0.0
# (0.0 pm 0.0)
#
# ==================================================
# norm norm
# --------------------------------------------------
#  1.01 pm 0.047
# (0.999 pm 0.00163)
#
# ==================================================
# tilt tilt
# --------------------------------------------------
#  0.00831 pm 0.0472
# (0.00395 pm 0.0)
#
# ==================================================
# reference reference
# --------------------------------------------------
#  1.0 pm 0.0
# (1.0 pm 0.0)

# %% [markdown]
# ## Likelihood Scan

# %%
fit_N = Fit(store_trace=False)
#result_N = fit_N.run([dataset_N])

# %%
# %%time 
parameter_standard = dataset_standard.models[0].parameters['amplitude']
parameter_N = dataset_N.models[0].parameters['amplitude']
parameter_N_frozen = dataset_N.models[0].parameters['amplitude']


parameter_standard.scan_values = np.linspace(
    parameter_standard.value-2*parameter_N.error,
    parameter_standard.value+2*parameter_N.error,
    10 )
f_standard = fit_standarad.stat_profile(
                    datasets =  [dataset_standard],
                    parameter=  parameter_standard, 
                    reoptimize = True ) 

parameter_N.scan_values = np.linspace(
    parameter_N.value-2*parameter_N.error,
    parameter_N.value+2*parameter_N.error,
    3 )
f_N = fit_N.stat_profile(
                    datasets =  [dataset_N],
                    parameter=  parameter_N, 
                    reoptimize = True ) 
parameter_N_frozen.scan_values = np.linspace(
    parameter_N.value-2*parameter_N.error,
    parameter_N.value+2*parameter_N.error,
    10 )
f_N_frozen = fit_N.stat_profile(
                    datasets =  [dataset_N],
                    parameter=  parameter_N_frozen, 
                    reoptimize = False )
# Out:
# <ValueView par_000_index=2.5895470610641205 par_001_lon_0=1.1891002622663838 par_002_lat_0=-2.530702881182409 par_003_norm=9.718320039782242 par_004_tilt=-3.6065096965928802>
# <ValueView par_000_index=2.589736363768552 par_001_lon_0=1.1890966638042266 par_002_lat_0=-2.530692788854466 par_003_norm=9.718302778244558 par_004_tilt=-3.6075155103797822>
# <ValueView par_000_index=2.5898617516681792 par_001_lon_0=1.1890959052440502 par_002_lat_0=-2.530681386970843 par_003_norm=9.718278886815767 par_004_tilt=-3.607935197557758>
# <ValueView par_000_index=2.5899294432215307 par_001_lon_0=1.189096084766818 par_002_lat_0=-2.53066849990613 par_003_norm=9.718232299346012 par_004_tilt=-3.6081711933984253>
# <ValueView par_000_index=2.589952752299143 par_001_lon_0=1.1890967217883561 par_002_lat_0=-2.530655678079174 par_003_norm=9.718174497479911 par_004_tilt=-3.6081974299565642>
# <ValueView par_000_index=2.589952163586238 par_001_lon_0=1.189097448149452 par_002_lat_0=-2.530642539290284 par_003_norm=9.718104485142135 par_004_tilt=-3.608099262147031>
# <ValueView par_000_index=2.5899357324183447 par_001_lon_0=1.1890981272141739 par_002_lat_0=-2.5306310819593665 par_003_norm=9.718036649075811 par_004_tilt=-3.6079099950065556>
# <ValueView par_000_index=2.589922875894598 par_001_lon_0=1.189098522311385 par_002_lat_0=-2.5306204723637853 par_003_norm=9.717969713246095 par_004_tilt=-3.607745413118456>
# <ValueView par_000_index=2.589910769778977 par_001_lon_0=1.1890988129591602 par_002_lat_0=-2.530609423301142 par_003_norm=9.717899805454588 par_004_tilt=-3.6075773576210084>
# <ValueView par_000_index=2.589887966217265 par_001_lon_0=1.1890991646902984 par_002_lat_0=-2.5305978275369303 par_003_norm=9.717825246003995 par_004_tilt=-3.6073774833292354>
# <ValueView par_000_index=2.561050513743163 par_001_lon_0=1.1890960962377572 par_002_lat_0=-2.530682426105401 par_003_norm=9.684758717344184 par_004_tilt=-2.3136700446206384 par_005_db0=-3.849187081602694 par_006_db1=-5.325863805475526 par_007_db2=-1.1128634981479009 par_008_db3=-8.889402730859597 par_009_db4=-8.757320228315143 par_010_db5=-8.927405441775578 par_011_db6=-7.0112233739637215 par_012_db7=-6.329834773580802 par_013_db8=-6.70711345658285 par_014_db9=-4.260564165647884 par_015_db10=-6.37808887292265 par_016_db11=-6.995044841053016 par_017_db12=-6.536999856267406 par_018_db13=-4.612602545308181 par_019_db14=-7.41262599361731 par_020_db15=-5.14060911705605 par_021_db16=-5.806125138778187 par_022_db17=-3.6009600437001983 par_023_db18=-4.244872479259487 par_024_db19=-5.623632313728204 par_025_db20=-2.54920693809608 par_026_db21=-4.9840964362497475 par_027_db22=-5.238050806939818 par_028_db23=-4.829344994514168 par_029_db24=-2.774884948399185 par_030_db25=8.162531714294115 par_031_db26=5.982468110872542 par_032_db27=4.7904015007341165 par_033_db28=3.982106445320473 par_034_db29=3.8076441071045095 par_035_db30=6.86379477754503 par_036_db31=7.597616524688225 par_037_db32=4.998668185433655 par_038_db33=5.652882797486388 par_039_db34=6.154027239079245 par_040_db35=5.417591404886983 par_041_db36=6.233021780582369 par_042_db37=7.252863771821332 par_043_db38=7.120843143816727 par_044_db39=6.89246320732047 par_045_db40=5.938990041918194 par_046_db41=4.679356788028906 par_047_db42=9.621272630743132 par_048_db43=9.559716777901022 par_049_db44=7.030874344691677 par_050_db45=4.739593190394331 par_051_db46=5.349379268723705 par_052_db47=6.315342242361547 par_053_db48=3.4397584367724443 par_054_db49=1.223753031871717>

# %%
f_standard

# %%
fig = plt.figure()
ax = plt.gca()
stat_standard =  f_standard['stat_scan'] -  min(f_standard['stat_scan'])
stat_N =  f_N['stat_scan'] -  min(f_N['stat_scan'])
stat_N_frozen =  f_N_frozen['stat_scan'] -  min(f_N_frozen['stat_scan'])

plt.plot(f_standard['amplitude_scan'],stat_standard, label = "Standard Analysus", 
         color = 'orange' )
plt.plot(f_N['amplitude_scan'], stat_N, label = "With Nuisance Parameters",
        color = 'green')
plt.plot(f_N_frozen['amplitude_scan'], stat_N_frozen, label = "With Nuisance Parameters frozen",
        color = 'blue')

ylim = ax.get_ylim()
plt.vlines(parameter_standard.value, ylim[0], ylim[1],
          color = 'orange')
plt.vlines(parameter_standard.value +parameter_standard.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'orange')
plt.vlines(parameter_standard.value -parameter_standard.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'orange')

plt.vlines(parameter_N.value, ylim[0], ylim[1],
          color = 'green')
plt.vlines(parameter_N.value +parameter_N.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'green')
plt.vlines(parameter_N.value -parameter_N.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'green')

plt.vlines(parameter_N.value, ylim[0], ylim[1],
          color = 'green')
plt.vlines(parameter_N.value +parameter_N.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'green')
plt.vlines(parameter_N.value -parameter_N.error , ylim[0], ylim[1], 
           linestyle=':',
          color = 'green')

plt.legend()

# %% [markdown]
# ## Fluxpoints of the Standard Analysis

# %%
fluxpoint_bins = dataset_standard.geoms['geom'].axes[0].edges[9:14].value
print(fluxpoint_bins)
# Out:
# [1.33352143 1.77827941 2.37137371 3.16227766 4.21696503]

# %%
from gammapy.estimators import FluxPointsEstimator
from my_estimator_points_sed_19 import My_FluxPointsEstimator
from my_estimator_points_core_19 import My_FluxPoints

# %%
fluxpointsestimator_standard = FluxPointsEstimator(
        energy_edges=fluxpoint_bins * u.TeV ,
        source=0,
        norm_min=0.2,
        norm_max=5,
        norm_n_values=11,
        norm_values=None,
        n_sigma=1,
        n_sigma_ul=2,
        reoptimize=False,
        selection_optional=["errn-errp", "ul","scan"],
    )

fluxpoints_standard = fluxpointsestimator_standard.run(dataset_standard)

# %%
fluxpoints_standard.to_table()
# Out:
# <Table length=4>
#       e_ref              e_min        ...      norm_scan [11]
#        TeV                TeV         ...
#      float64            float64       ...         float64
# ------------------ ------------------ ... ------------------------
# 1.5399265260594919  1.333521432163324 ... 0.2 .. 4.999999999999999
#  2.053525026457146 1.7782794100389228 ... 0.2 .. 4.999999999999999
# 2.7384196342643614  2.371373705661655 ... 0.2 .. 4.999999999999999
#  3.651741272548377 3.1622776601683795 ... 0.2 .. 4.999999999999999

# %%
from gammapy.datasets import FluxPointsDataset
fluxpoints_standard.is_ul = fluxpoints_standard.ts < 4
#fluxpoints_standard.write(dataset_name_folder + 'Standard_flux_'+analysis_folder+ '.fits', overwrite= True)
flux_points_dataset_standard = FluxPointsDataset(data=fluxpoints_standard,
                                               models=dataset_standard.models[0])

# %%
#ax_spectrum, ax_residuals =
flux_points_dataset_standard.plot_fit()
# Out:
# (<AxesSubplot:xlabel='Energy [TeV]', ylabel='e2dnde [erg / (cm2 s)]'>,
#  <AxesSubplot:xlabel='Energy [TeV]', ylabel='Residuals\n (data - model) / model'>)

# %%
fig  = plt.figure()
ax = plt.gca()
fluxpoints_standard.plot_ts_profiles()
# Out:
# <AxesSubplot:xlabel='Energy [TeV]', ylabel='dnde (1 / (cm2 s TeV))'>

# %% [markdown]
# ## Fluxpoints of Nuisance Pseudo Dataset

# %%
dataset_pseudo_N = dataset_standard.copy()
'''models = Models.from_dict(nui_model)
# gets somehow read into as an int which causes problems when printing with precison
models.parameters['reference'].error = float(models.parameters['reference'].error)
with open(outputfile+'/nui_bgmodel.yml', 'r') as file:
    nui_bg_model = yaml.full_load(file)
bkg_model = FoVBackgroundModel(dataset_name = dataset_pseudo_N.name, )
models.append(bkg_model)
dataset_pseudo_N.models =models
dataset_pseudo_N.background_model.parameters['tilt'].frozen = True
dataset_pseudo_N.background_model.parameters['norm'].frozen = True'''

with open(f'{pathsource}nui_model{added}.yml', "r") as ymlfile:
    best_fit_model = yaml.load(ymlfile, Loader=yaml.FullLoader)

bkg_model_ = FoVBackgroundModel(dataset_name=dataset_pseudo_N.name)
# keep values at 0 and 1!!
models_ = Models.from_dict(best_fit_model )
models_.append(bkg_model_)
dataset_pseudo_N.models =models_

dataset_pseudo_N.background = dataset_N.npred_background()

# %%
fluxpointsestimator_pseudo_N = FluxPointsEstimator(
        energy_edges=fluxpoint_bins * u.TeV ,
        source=0,
        norm_min=0.2,
        norm_max=5,
        norm_n_values=11,
        norm_values=None,
        n_sigma=1,
        n_sigma_ul=2,
        reoptimize=False,
        selection_optional=["errn-errp", "ul","scan"],
    )

fluxpoints_pseudo_N = fluxpointsestimator_pseudo_N.run(dataset_pseudo_N)

# %%
fluxpoints_pseudo_N.to_table()
# Out:
# <Table length=4>
#       e_ref              e_min        ...      norm_scan [11]
#        TeV                TeV         ...
#      float64            float64       ...         float64
# ------------------ ------------------ ... ------------------------
# 1.5399265260594919  1.333521432163324 ... 0.2 .. 4.999999999999999
#  2.053525026457146 1.7782794100389228 ... 0.2 .. 4.999999999999999
# 2.7384196342643614  2.371373705661655 ... 0.2 .. 4.999999999999999
#  3.651741272548377 3.1622776601683795 ... 0.2 .. 4.999999999999999

# %%
fluxpoints_pseudo_N.is_ul = fluxpoints_pseudo_N.ts < 4
#fluxpoints_standard.write(dataset_name_folder + 'Standard_flux_'+analysis_folder+ '.fits', overwrite= True)
flux_points_dataset_pseudo_N = FluxPointsDataset(data=fluxpoints_pseudo_N,
                                               models=dataset_pseudo_N.models[0])

# %%
#ax_spectrum, ax_residuals =
flux_points_dataset_pseudo_N.plot_fit()
# Out:
# (<AxesSubplot:xlabel='Energy [TeV]', ylabel='e2dnde [erg / (cm2 s)]'>,
#  <AxesSubplot:xlabel='Energy [TeV]', ylabel='Residuals\n (data - model) / model'>)

# %% [markdown]
# ## Fluxpoints of the Dataset with Nuisance Parameters

# %%
# reoptimize=False
compute = 1
if compute :
    fluxpointsestimator_N_frozen = My_FluxPointsEstimator(
            energy_edges=fluxpoint_bins * u.TeV ,
            source=0,
            norm_min=0.2,
            norm_max=5,
            norm_n_values=11,
            norm_values=None,
            n_sigma=1,
            n_sigma_ul=2,
            reoptimize=False,
            selection_optional=["errn-errp","ul",  "scan"],
        )

    fluxpoints_N_frozen = fluxpointsestimator_N_frozen.run([dataset_N])
    fluxpoints_N_frozen.write(f'{source}/nui_fluxpoints_frozen.fits',overwrite= True )
else:
    fluxpoints_N_frozen = My_FluxPoints.read(f'{source}/nui_fluxpoints_frozen.fits')
# Out:
# E:  1.333521432163324 TeV : 1.7782794100389228 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 17
# 	total stat : -229450.85
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 17
# 	total stat : -229450.85
#
#
# ... computing errn-errp
# norm_errp:  0.01647059886396587
# norm_errn:  0.01631583804766166
# ... computing ul
# ul:  {'norm': 0.9925251268155868, 'stat': -229450.84543170728, 'success': True, 'norm_err': 0.0163924934986681, 'ts': 13194.098982172, 'npred': array([62948.77094885]), 'norm_errp': 0.01647059886396587, 'norm_errn': 0.01631583804766166, 'norm_ul': 1.0256648340631918}
# ... computing scan
# scan:  {'norm': 0.9925251268155868, 'stat': -229450.84543170728, 'success': True, 'norm_err': 0.0163924934986681, 'ts': 13194.098982172, 'npred': array([62948.77094885]), 'norm_errp': 0.01647059886396587, 'norm_errn': 0.01631583804766166, 'norm_ul': 1.0256648340631918, 'norm_scan': array([0.2       , 0.27594593, 0.38073079, 0.52530556, 0.72477966,
#        1.        , 1.37972966, 1.90365394, 2.6265278 , 3.62389832,
#        5.        ]), 'stat_scan': array([-224590.70340312, -225917.01183925, -227194.00056698,
#        -228314.90082891, -229133.6614392 , -229450.64080687,
#        -228992.19069226, -227382.00190347, -224101.2772769 ,
#        -218433.64012408, -209389.08234557])}
# E:  1.7782794100389228 TeV : 2.371373705661655 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 20
# 	total stat : -134988.47
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 20
# 	total stat : -134988.47
#
#
# ... computing errn-errp
# norm_errp:  0.018783222840673908
# norm_errn:  0.01857625515745518
# ... computing ul
# ul:  {'norm': 0.9683011881052341, 'stat': -134988.47460734332, 'success': True, 'norm_err': 0.018680074587054903, 'ts': 9918.302051608567, 'npred': array([45759.47336962]), 'norm_errp': 0.018783222840673908, 'norm_errn': 0.01857625515745518, 'norm_ul': 1.0060464648265932}
# ... computing scan
# scan:  {'norm': 0.9683011881052341, 'stat': -134988.47460734332, 'success': True, 'norm_err': 0.018680074587054903, 'ts': 9918.302051608567, 'npred': array([45759.47336962]), 'norm_errp': 0.018783222840673908, 'norm_errn': 0.01857625515745518, 'norm_ul': 1.0060464648265932, 'norm_scan': array([0.2       , 0.27594593, 0.38073079, 0.52530556, 0.72477966,
#        1.        , 1.37972966, 1.90365394, 2.6265278 , 3.62389832,
#        5.        ]), 'stat_scan': array([-131477.34073069, -132460.00045869, -133397.41953376,
#        -134209.98289704, -134788.96140123, -134985.64280737,
#        -134595.90831012, -133338.66147361, -130825.89740088,
#        -126521.32591237, -119683.26367861])}
# E:  2.371373705661655 TeV : 3.1622776601683795 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 15
# 	total stat : -79828.61
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 15
# 	total stat : -79828.61
#
#
# ... computing errn-errp
# norm_errp:  0.022256365676451575
# norm_errn:  0.021975748642679704
# ... computing ul
# ul:  {'norm': 0.9853218530054555, 'stat': -79828.60831853941, 'success': True, 'norm_err': 0.022112338645888022, 'ts': 7465.375378506404, 'npred': array([33668.0907811]), 'norm_errp': 0.022256365676451575, 'norm_errn': 0.021975748642679704, 'norm_ul': 1.0303082703533022}
# ... computing scan
# scan:  {'norm': 0.9853218530054555, 'stat': -79828.60831853941, 'success': True, 'norm_err': 0.022112338645888022, 'ts': 7465.375378506404, 'npred': array([33668.0907811]), 'norm_errp': 0.022256365676451575, 'norm_errn': 0.021975748642679704, 'norm_ul': 1.0303082703533022, 'norm_scan': array([0.2       , 0.27594593, 0.38073079, 0.52530556, 0.72477966,
#        1.        , 1.37972966, 1.90365394, 2.6265278 , 3.62389832,
#        5.        ]), 'stat_scan': array([-77181.21610659, -77913.77819748, -78613.59846251, -79223.10761458,
#        -79663.76999338, -79828.18232307, -79568.83598867, -78682.36906731,
#        -76887.69625574, -73795.77764335, -68867.91258011])}
# E:  3.1622776601683795 TeV : 4.216965034285822 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 20
# 	total stat : -48050.46
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 20
# 	total stat : -48050.46
#
#
# ... computing errn-errp
# norm_errp:  0.026617254677957194
# norm_errn:  0.02620637383486404
# ... computing ul
# ul:  {'norm': 0.9730014059926789, 'stat': -48050.460000977226, 'success': True, 'norm_err': 0.02641192323721447, 'ts': 5037.2061457072705, 'npred': array([26090.44086793]), 'norm_errp': 0.026617254677957194, 'norm_errn': 0.02620637383486404, 'norm_ul': 1.026630551072328}
# ... computing scan
# scan:  {'norm': 0.9730014059926789, 'stat': -48050.460000977226, 'success': True, 'norm_err': 0.02641192323721447, 'ts': 5037.2061457072705, 'npred': array([26090.44086793]), 'norm_errp': 0.026617254677957194, 'norm_errn': 0.02620637383486404, 'norm_ul': 1.026630551072328, 'norm_scan': array([0.2       , 0.27594593, 0.38073079, 0.52530556, 0.72477966,
#        1.        , 1.37972966, 1.90365394, 2.6265278 , 3.62389832,
#        5.        ]), 'stat_scan': array([-46269.41096034, -46766.26870032, -47240.38302485, -47651.95289644,
#        -47946.52353434, -48049.43002144, -47857.88308504, -47229.85449644,
#        -45968.61353758, -43801.32615429, -40349.50976544])}

# %%
#reoptimize=True

compute = 1
if compute :
    fluxpointsestimator_N = My_FluxPointsEstimator(
            energy_edges=fluxpoint_bins * u.TeV ,
            source=0,
            norm_min=0.2,
            norm_max=5,
            norm_n_values=11,
            norm_values=None,
            n_sigma=1,
            n_sigma_ul=2,
            reoptimize=True,
            selection_optional=["errn-errp",],
        )

    fluxpoints_N = fluxpointsestimator_N.run([dataset_N])
    fluxpoints_N.write(f'{source}/nui_fluxpoints2.fits',overwrite= True )
else:
    fluxpoints_N = My_FluxPoints.read(f'{source}/nui_fluxpoints.fits')
# Out:
# E:  1.333521432163324 TeV : 1.7782794100389228 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 2412
# 	total stat : -229465.43
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 2412
# 	total stat : -229465.43
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (101.05683031, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (101.05683031, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (66.2049747, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (66.2049747, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 37.36439596)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 37.36439596)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 5.95329463)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 5.95329463)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (257.89018059, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (257.89018059, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (269.37162442, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (269.37162442, 22.01838034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 61.16004565)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, 61.16004565)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, -22.51415239)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6309025, -22.51415239)> is outside valid IRF map range, using nearest IRF defined within
# ... computing errn-errp
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.7249063, 20.70055804)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.7249063, 20.70055804)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (235.66247515, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (235.66247515, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (36.6876363, -15.25866505)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (36.6876363, -15.25866505)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (330.02467746, 9.65417064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (330.02467746, 9.65417064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (67.50518357, 17.95761674)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (67.50518357, 17.95761674)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (339.33876597, 20.72359176)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (339.33876597, 20.72359176)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (308.15286306, 21.64057178)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (308.15286306, 21.64057178)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (53.27769729, 21.93373856)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (53.27769729, 21.93373856)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.4516835, 22.05467507)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.4516835, 22.05467507)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63457389, 21.75735698)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63457389, 21.75735698)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63513432, 21.98938904)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63513432, 21.98938904)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63125068, 21.93754753)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63125068, 21.93754753)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62601271, 22.06082899)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62601271, 22.06082899)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63094533, 22.05077103)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63094533, 22.05077103)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63273362, 21.83419087)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63273362, 21.83419087)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63157813, 21.9683499)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63157813, 21.9683499)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63082198, 22.04284787)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63082198, 22.04284787)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63114715, 21.95359151)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63114715, 21.95359151)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63144765, 22.1040036)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63144765, 22.1040036)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.60948607, 22.55405622)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.60948607, 22.55405622)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63117599, 21.94871125)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63117599, 21.94871125)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63080692, 22.04107856)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63080692, 22.04107856)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.6305019, 22.08653373)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.6305019, 22.08653373)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63083689, 22.03017265)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63083689, 22.03017265)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63092406, 21.99140731)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63092406, 21.99140731)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63084462, 22.035884)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63084462, 22.035884)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63164519, 21.90412604)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63164519, 21.90412604)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (26.34888075, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (26.34888075, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (125.05894199, -14.90403496)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (125.05894199, -14.90403496)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (148.68822824, 10.06405179)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (148.68822824, 10.06405179)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (274.21480986, 18.37055609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (274.21480986, 18.37055609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (308.54679704, 21.08764288)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (308.54679704, 21.08764288)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (63.22395695, 21.87780905)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (63.22395695, 21.87780905)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63078331, 22.03816775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63078331, 22.03816775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63152512, 22.11077701)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63152512, 22.11077701)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (112.11632132, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (112.11632132, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.94632408, -14.724193)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.94632408, -14.724193)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (131.36877659, 10.28469317)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (131.36877659, 10.28469317)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (36.2010321, 18.58467679)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (36.2010321, 18.58467679)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.91324825, 21.24544081)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.91324825, 21.24544081)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.90921324, 21.9364876)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.90921324, 21.9364876)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.74447634, 22.03577603)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.74447634, 22.03577603)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6309092, 21.996998)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6309092, 21.996998)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62955488, 21.86959378)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62955488, 21.86959378)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63101599, 22.06404695)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63101599, 22.06404695)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63134636, 21.92883583)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63134636, 21.92883583)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63081468, 22.0430431)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63081468, 22.0430431)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63076702, 22.05371422)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63076702, 22.05371422)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63099719, 22.04789299)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63099719, 22.04789299)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.85799066, 21.69986775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.85799066, 21.69986775)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.84750656, 20.12367183)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.84750656, 20.12367183)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.83236187, 23.66698625)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.83236187, 23.66698625)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62628279, 22.26694108)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62628279, 22.26694108)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63084478, 22.03379669)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63084478, 22.03379669)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63109631, 21.96199)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63109631, 21.96199)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (58.98269215, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (58.98269215, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (106.07175784, -15.21152135)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (106.07175784, -15.21152135)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (238.24103703, 9.70536659)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (238.24103703, 9.70536659)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (42.22523758, 18.01073779)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (42.22523758, 18.01073779)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (95.89665044, 20.77565687)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (95.89665044, 20.77565687)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (350.36688227, 21.68507344)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (350.36688227, 21.68507344)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (67.32691155, 21.96011043)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (67.32691155, 21.96011043)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63099977, 22.05975868)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63099977, 22.05975868)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63095406, 21.98681059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63095406, 21.98681059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63062289, 22.01620762)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63062289, 22.01620762)> is outside valid IRF map range, using nearest IRF defined within
# norm_errp:  0.0
# norm_errn:  0.016323932579208035
# E:  1.7782794100389228 TeV : 2.371373705661655 TeV
# ... computing estimate best fit
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 11344
# 	total stat : -135013.64
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 11344
# 	total stat : -135013.64
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 27.8877281)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 27.8877281)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 16.04979311)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 16.04979311)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (102.8931127, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (102.8931127, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (64.37156754, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (64.37156754, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 61.16087034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 61.16087034)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, -22.513064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, -22.513064)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (102.8931127, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (102.8931127, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (64.37156754, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (64.37156754, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (276.24006593, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (276.24006593, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (251.02461431, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (251.02461431, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (209.70959823, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (209.70959823, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (317.55508201, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (317.55508201, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (264.40492123, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (264.40492123, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (262.85975901, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (262.85975901, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (91.35815123, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (91.35815123, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (75.90652901, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (75.90652901, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 32.12792359)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63234012, 11.60550019)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (353.70632527, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (173.55835498, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51134752, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75333273, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.42241411, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84226614, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.53307998, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.73160027, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.63973864, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.62494161, 22.01947031)> is outside valid IRF map range, using nearest IRF defined within
# ... computing errn-errp
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63227054, 22.05667182)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63227054, 22.05667182)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.44165552, 22.07213842)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.44165552, 22.07213842)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63229726, 22.04865456)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63229726, 22.04865456)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63280435, 22.00621198)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63280435, 22.00621198)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63155014, 21.89531457)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63155014, 21.89531457)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63264389, 22.00221139)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63264389, 22.00221139)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63249537, 22.03861596)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63249537, 22.03861596)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63233953, 21.9980208)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63233953, 21.9980208)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63244376, 21.96635843)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63244376, 21.96635843)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.56623516, 20.94734684)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.56623516, 20.94734684)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (312.89678196, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (312.89678196, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (133.80017855, -15.21642688)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (133.80017855, -15.21642688)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (317.62217066, 9.69749881)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (317.62217066, 9.69749881)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (18.94047267, 18.0019654)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (18.94047267, 18.0019654)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (40.11369354, 20.76721733)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (40.11369354, 20.76721733)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (169.84538311, 21.67838719)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (169.84538311, 21.67838719)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (99.40192022, 21.9571314)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (99.40192022, 21.9571314)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63226245, 21.98075902)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63226245, 21.98075902)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63245885, 21.98264783)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63245885, 21.98264783)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6328785, 21.91599059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6328785, 21.91599059)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (286.43809832, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (286.43809832, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (69.04890586, -15.09158079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (69.04890586, -15.09158079)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (232.9310812, 9.85578286)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (232.9310812, 9.85578286)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (166.91806305, 18.1676966)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (166.91806305, 18.1676966)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (261.93202224, 20.92029675)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (261.93202224, 20.92029675)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (45.57386105, 21.78925591)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (45.57386105, 21.78925591)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63221429, 22.05195066)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63221429, 22.05195066)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63113679, 21.87423787)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
# ...
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75308902, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.41972702, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.41972702, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84402156, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84402156, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.51040158, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.51040158, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.753347, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.753347, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.41714717, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.41714717, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.84660142, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.84660142, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.48460307, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.48460307, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (175.77914552, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (175.77914552, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51065957, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51065957, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75308902, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75308902, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63187429, 32.12411533)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63187429, 32.12411533)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63187429, 11.60406804)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63187429, 11.60406804)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51065957, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (123.51065957, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75308902, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (43.75308902, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.41972702, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (122.41972702, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84402156, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (44.84402156, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.51040158, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (111.51040158, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.753347, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (55.753347, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.41714717, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (2.41714717, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.84660142, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (164.84660142, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.48460307, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (351.48460307, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (175.77914552, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (175.77914552, 22.01679368)> is outside valid IRF map range, using nearest IRF defined within
# ... computing errn-errp
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63983769, 21.63036831)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63983769, 21.63036831)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (74.17258877, 22.02144568)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (74.17258877, 22.02144568)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63180087, 22.04699651)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63180087, 22.04699651)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6336706, 21.90053325)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6336706, 21.90053325)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.81515742, 22.04593217)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.81515742, 22.04593217)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63149234, 22.03717263)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63149234, 22.03717263)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.67235044, 21.6924236)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.67235044, 21.6924236)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63235041, 21.97919085)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63235041, 21.97919085)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63071998, 22.05551525)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63071998, 22.05551525)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.67222034, 22.24389342)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.67222034, 22.24389342)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (154.19387972, 90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (154.19387972, 90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62482724, 21.86858487)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62482724, 21.86858487)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.64279528, 22.13506545)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.64279528, 22.13506545)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (319.07920989, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (319.07920989, -90.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (228.37896776, -5.53708075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (228.37896776, -5.53708075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (141.18749258, 14.76850166)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (141.18749258, 14.76850166)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (47.57554245, 19.94024813)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (47.57554245, 19.94024813)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (328.98184728, 21.41569389)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (328.98184728, 21.41569389)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (56.30115725, 21.87351912)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (56.30115725, 21.87351912)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63108297, 22.04779381)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63108297, 22.04779381)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6402685, 22.1204803)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.6402685, 22.1204803)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62971836, 21.94130851)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62971836, 21.94130851)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63096215, 21.96465245)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63096215, 21.96465245)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.61473209, 22.16463075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.61473209, 22.16463075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63674033, 21.89294991)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63674033, 21.89294991)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.55584397, 22.32800429)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.55584397, 22.32800429)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63046815, 21.94859671)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.63046815, 21.94859671)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65124726, 21.77139685)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.65124726, 21.77139685)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.61952972, 21.82631376)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.61952972, 21.82631376)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63472182, 22.07726053)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63472182, 22.07726053)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.64804502, 21.79152792)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.64804502, 21.79152792)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.66286616, 21.71869045)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.66286616, 21.71869045)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63216061, 21.945075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (73.63216061, 21.945075)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62907189, 22.01774534)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (ICRS): (ra, dec) in deg
#     (93.62907189, 22.01774534)> is outside valid IRF map range, using nearest IRF defined within
# norm_errp:  0.0
# norm_errn:  0.026213037267723217

# %%
fluxpoints_N.to_table()
# Out:
# <Table length=3>
#       e_ref              e_min              e_max        ... counts [1] success
#        TeV                TeV                TeV         ...
#      float64            float64            float64       ...  float64     bool
# ------------------ ------------------ ------------------ ... ---------- -------
# 0.6493816315762113 0.5623413251903491 0.7498942093324559 ...    26401.0    True
# 0.8659643233600653 0.7498942093324559                1.0 ...   100309.0    True
# 1.1547819846894583                1.0  1.333521432163324 ...    71596.0    True

# %%
fluxpoints_N.is_ul = fluxpoints_N.ts < 4

flux_points_dataset_N = FluxPointsDataset(data=fluxpoints_N,
                                               models=dataset_N.models[0])

# %%
ax_spectrum, ax_residuals = flux_points_dataset_N.plot_fit()

# %%
fig = plt.figure(figsize = (8,9))

ax_spectrum, ax_residuals = flux_points_dataset_standard.plot_fit()
'''    kwargs_spectrum={ 
                     'label':'Standard Analyis' },
    kwargs_residuals={'color':'blue',
                     'label':'Standard Analyis'});'''



flux_points_dataset_N.plot_fit(
    #kwargs_spectrum={
    #                'label':'Analyis Nuisance 2deg'},
                               ax_spectrum = ax_spectrum, ax_residuals = ax_residuals,
                    kwargs_residuals={'color':'green', 
                                      'label':'Analyis Nuisance'});
ax_spectrum.legend();
ax_residuals.legend();
ax_residuals.set_ylim(-0.2,0.2)
# Out:
# (-0.2, 0.2)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,7))
for i in [0,1]:
    e_min, e_max = fluxpoints_standard.to_table()['e_min'][i], fluxpoints_standard.to_table()['e_max'][i]
    stat_stand = fluxpoints_standard.to_table()['stat_scan'][i] - min(fluxpoints_standard.to_table()['stat_scan'][i])
    stat_N = fluxpoints_N.to_table()['stat_scan'][i] - min(fluxpoints_N.to_table()['stat_scan'][i])
    stat_N_frozen = fluxpoints_N_frozen.to_table()['stat_scan'][i] - min(fluxpoints_N_frozen.to_table()['stat_scan'][i])


    ax[i].plot(fluxpoints_standard.to_table()['norm_scan'][i],
             stat_stand,
             label ="standard",
              color = 'orange')
    ax[i].plot(fluxpoints_N.to_table()['norm_scan'][i],
             stat_N, 'o',
             label ="nuisance", 
              color = 'green')
    
    ax[i].plot(fluxpoints_N_frozen.to_table()['norm_scan'][i],
             stat_N,
             label ="nuisance frozen", 
              color = 'blue')
    
        
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i], ylim[0],ylim[1],  color = 'green')
    '''ax[i].vlines(fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)'''
    ax[i].vlines(fluxpoints_N.to_table()['norm_ul'][i],
                 ylim[0],ylim[1],linestyle='--', color = 'green',)
    ax[i].fill_betweenx(ylim,
                        fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i], 
                        fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                        color = 'green' , alpha = 0.3)
    
    ax[i].vlines(fluxpoints_N_frozen.to_table()['norm'][i], ylim[0],ylim[1], color = 'blue')
    '''ax[i].vlines(fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)'''
    ax[i].vlines(fluxpoints_N_frozen.to_table()['norm_ul'][i],
                 ylim[0],ylim[1],linestyle='--', color = 'blue',)
    ax[i].fill_betweenx(ylim,
                        fluxpoints_N_frozen.to_table()['norm'][i]-fluxpoints_N_frozen.to_table()['norm_errn'][i], 
                        fluxpoints_N_frozen.to_table()['norm'][i]+fluxpoints_N_frozen.to_table()['norm_err'][i],
                        color = 'blue' , alpha = 0.1)
    ax[i].legend(); ax[i].set_title("Energy: [{:.1}:{:.1}] TeV".format(e_min, e_max))
    ax[i].set_ylim(-5,10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12316/2755992420.py in <module>
#       3     e_min, e_max = fluxpoints_standard.to_table()['e_min'][i], fluxpoints_standard.to_table()['e_max'][i]
#       4     stat_stand = fluxpoints_standard.to_table()['stat_scan'][i] - min(fluxpoints_standard.to_table()['stat_scan'][i])
# ----> 5     stat_N = fluxpoints_N.to_table()['stat_scan'][i] - min(fluxpoints_N.to_table()['stat_scan'][i])
#       6     stat_N_frozen = fluxpoints_N_frozen.to_table()['stat_scan'][i] - min(fluxpoints_N_frozen.to_table()['stat_scan'][i])
#       7
#
# ~/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1865     def __getitem__(self, item):
#    1866         if isinstance(item, str):
# -> 1867             return self.columns[item]
#    1868         elif isinstance(item, (int, np.integer)):
#    1869             return self.Row(self, item)
#
# ~/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/table/table.py in __getitem__(self, item)
#     244         """
#     245         if isinstance(item, str):
# --> 246             return OrderedDict.__getitem__(self, item)
#     247         elif isinstance(item, (int, np.integer)):
#     248             return list(self.values())[item]
#
# KeyError: 'stat_scan'

# %%
fig, ax = plt.subplots(1,2, figsize = (15,7))
for i in [0,1]:
    e_min, e_max = fluxpoints_standard.to_table()['e_min'][i], fluxpoints_standard.to_table()['e_max'][i]
    stat_stand = fluxpoints_standard.to_table()['stat_scan'][i] - min(fluxpoints_standard.to_table()['stat_scan'][i])
    stat_N = fluxpoints_N.to_table()['stat_scan'][i] - min(fluxpoints_N.to_table()['stat_scan'][i])
    stat_pseudo_N = fluxpoints_pseudo_N.to_table()['stat_scan'][i] - min(fluxpoints_pseudo_N.to_table()['stat_scan'][i])


    ax[i].plot(fluxpoints_standard.to_table()['norm_scan'][i],
             stat_stand,
             label ="standard",
              color = 'orange')
    ax[i].plot(fluxpoints_N.to_table()['norm_scan'][i],
             stat_N, 'o',
             label ="nuisance", 
              color = 'green')
    
    ax[i].plot(fluxpoints_pseudo_N.to_table()['norm_scan'][i],
             stat_N,
             label ="pseudo nuisance", 
              color = 'blue')
    
    ylim = ax[i].get_ylim()
    ax[i].vlines(fluxpoints_standard.to_table()['norm'][i], ylim[0],ylim[1], color = 'orange')
    '''ax[i].vlines(fluxpoints_standard.to_table()['norm'][i]+fluxpoints_standard.to_table()['norm_errp'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'orange',)
    ax[i].vlines(fluxpoints_standard.to_table()['norm'][i]-fluxpoints_standard.to_table()['norm_errn'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'orange',)'''
    ax[i].vlines(fluxpoints_standard.to_table()['norm_ul'][i],
                 ylim[0],ylim[1],linestyle='--', color = 'orange',)
    xmin = fluxpoints_standard.to_table()['norm'][i]-fluxpoints_standard.to_table()['norm_errn'][i]
    if np.isnan(xmin):
        xmin = 0
    ax[i].fill_betweenx(ylim,
                        xmin, 
                        fluxpoints_standard.to_table()['norm'][i]+fluxpoints_standard.to_table()['norm_errp'][i],
                        color = 'orange' , alpha = 0.3)
    
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i], ylim[0],ylim[1],  color = 'green')
    '''ax[i].vlines(fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)'''
    ax[i].vlines(fluxpoints_N.to_table()['norm_ul'][i],
                 ylim[0],ylim[1],linestyle='--', color = 'green',)
    ax[i].fill_betweenx(ylim,
                        fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i], 
                        fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                        color = 'green' , alpha = 0.3)
    
    ax[i].vlines(fluxpoints_pseudo_N.to_table()['norm'][i], ylim[0],ylim[1], color = 'blue')
    '''ax[i].vlines(fluxpoints_N.to_table()['norm'][i]+fluxpoints_N.to_table()['norm_err'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)
    ax[i].vlines(fluxpoints_N.to_table()['norm'][i]-fluxpoints_N.to_table()['norm_errn'][i],
                 ylim[0],ylim[1],linestyle=':', color = 'green',)'''
    ax[i].vlines(fluxpoints_pseudo_N.to_table()['norm_ul'][i],
                 ylim[0],ylim[1],linestyle='--', color = 'blue',)
    ax[i].fill_betweenx(ylim,
                        fluxpoints_pseudo_N.to_table()['norm'][i]-fluxpoints_pseudo_N.to_table()['norm_errn'][i], 
                        fluxpoints_pseudo_N.to_table()['norm'][i]+fluxpoints_pseudo_N.to_table()['norm_err'][i],
                        color = 'blue' , alpha = 0.1)
    ax[i].legend(); ax[i].set_title("Energy: [{:.1}:{:.1}] TeV".format(e_min, e_max))
    ax[i].set_ylim(-5,10)

# %%
sys.path.append('/home/hpc/caph/mppi045h/3D_analysis/')
import upper_limit_18_02
for i in [0,1]:
    print('='*20)
    e_min, e_max = fluxpoints_standard.to_table()['e_min'][i], fluxpoints_standard.to_table()['e_max'][i]
    print("Energy: [{:.1}:{:.1}] TeV".format(e_min, e_max))
    print()
    l_standard = dict()
    l_standard['scale_scan'] =fluxpoints_standard.to_table()['norm_scan'][i]
    stat_stand = fluxpoints_standard.to_table()['stat_scan'][i] - min(fluxpoints_standard.to_table()['stat_scan'][i])
    l_standard['stat_scan'] =stat_stand

    stat_N = fluxpoints_N.to_table()['stat_scan'][i] - min(fluxpoints_N.to_table()['stat_scan'][i])
    print('-'*20)
    print("Standard:")
    print("From Fluxpints:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(fluxpoints_standard.to_table()['norm'][i],
                                                   fluxpoints_standard.to_table()['norm_err'][i],
                                                   fluxpoints_standard.to_table()['norm_ul'][i]))


    ul = upper_limit_18_02.upper_limit(likelihood = l_standard, mass = 0 ,scale = 0)
    trippel = ul.likelihood_upper()
    print("From UL module:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(trippel[0][0],
                                                   trippel[1][0],
                                                   trippel[2]))
    l_N = dict()
    l_N['scale_scan'] =fluxpoints_standard.to_table()['norm_scan'][i]
    stat_N = fluxpoints_N.to_table()['stat_scan'][i] - min(fluxpoints_N.to_table()['stat_scan'][i])
    l_N['stat_scan'] =stat_N

    print('-'*20)
    print("Nuisance:")
    print("From Fluxpints:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(fluxpoints_N.to_table()['norm'][i],
                                                   fluxpoints_N.to_table()['norm_err'][i],
                                                   fluxpoints_N.to_table()['norm_ul'][i]))


    ul = upper_limit_18_02.upper_limit(likelihood = l_N, mass = 0 ,scale = 0)
    trippel = ul.likelihood_upper()
    print("From UL module:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(trippel[0][0],
                                                   trippel[1][0],
                                                   trippel[2]))
    
    
    l_pseudo_N = dict()
    l_pseudo_N['scale_scan'] =fluxpoints_standard.to_table()['norm_scan'][i]
    stat_pseudo_N = fluxpoints_pseudo_N.to_table()['stat_scan'][i] - min(fluxpoints_pseudo_N.to_table()['stat_scan'][i])
    l_pseudo_N['stat_scan'] =stat_pseudo_N

    print('-'*20)
    print(" Pseudo Nuisance:")
    print("From Fluxpints:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(fluxpoints_pseudo_N.to_table()['norm'][i],
                                                   fluxpoints_pseudo_N.to_table()['norm_err'][i],
                                                   fluxpoints_pseudo_N.to_table()['norm_ul'][i]))


    ul = upper_limit_18_02.upper_limit(likelihood = l_pseudo_N, mass = 0 ,scale = 0)
    trippel = ul.likelihood_upper()
    print("From UL module:")
    print("norm: {:.3} pm {:.3} (UL: {:.3})".format(trippel[0][0],
                                                   trippel[1][0],
                                                   trippel[2]))

    print()
