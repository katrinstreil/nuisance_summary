# %%
import sys
sys.path.append('../')

import Dataset_load
from gammapy.modeling.models import Models

# %%
c = Dataset_load.load_config()
awo, aw, ewo, ew = c['_colors'] 
folder = c['folder']
livetime  = c['livetime']

# %%
def get_sym_datasets(sys, notes, nui, lt = f'_livetime_{livetime}'):
    models = []
    for s, n in zip (sys, notes):
        path = f'../{s}/data/0_model{nui}{lt}{n}.yml'
        models.append(Models.read(path))
    return models

# %%
sys = [
       'Eff_area100_PKSflare_crab_cutoff',
       'E_reco_PKSflare_crab_cutoff',
    'Combined100_PKSflare_crab_cutoff', 
       
      ]

notes = ['_np', "_np", "_np"]

models = get_sym_datasets(sys, notes, nui  = "_nui")



notes = ['_np', "_np", "_np"]

models_no = get_sym_datasets(sys, notes, nui = '')

# %%
 # sym models
    

notes = ["_30",  '_1000', "_1000"]

models_sym = get_sym_datasets(sys, notes, nui  = "_nui")



notes = ['', "", ""]

models_no_sym = get_sym_datasets(sys, notes, nui  = "")

# %%
sys = [
       'Eff_area100_double_PKSflare_crab_cutoff',
       'E_reco_double_PKSflare_crab_cutoff',
    'Combined100_double_PKSflare_crab_cutoff', 
       
      ]

notes = ["_1000",  '_1000', "_3000"]


models_double = get_sym_datasets(sys, notes, nui  = "_nui", lt = '' )

# %%
for m in models:
    print(m[0])
# Out:
# SkyModel
#
#   Name                      : 92gHQ4qx
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                      :      2.302  +/-    0.09
#     amplitude                  :   3.85e-11  +/- 5.9e-12 1 / (cm2 s TeV)
#     reference  (frozen)        :      1.000      TeV
#     lambda_                    :      0.100  +/-    0.04 1 / TeV
#     alpha      (frozen)        :      1.000
#     lon_0                      :    329.680  +/-    0.00 deg
#     lat_0                      :    -30.222  +/-    0.00 deg
#
#
# SkyModel
#
#   Name                      : 1bpdX3kR
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                      :      2.299  +/-    0.13
#     amplitude                  :   3.85e-11  +/- 2.6e-12 1 / (cm2 s TeV)
#     reference  (frozen)        :      1.000      TeV
#     lambda_                    :      0.100  +/-    0.04 1 / TeV
#     alpha      (frozen)        :      1.000
#     lon_0                      :    329.680  +/-    0.00 deg
#     lat_0                      :    -30.222  +/-    0.00 deg
#
#
# SkyModel
#
#   Name                      : U64xP7x-
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                      :      2.299  +/-    0.13
#     amplitude                  :   3.85e-11  +/- 6.0e-12 1 / (cm2 s TeV)
#     reference  (frozen)        :      1.000      TeV
#     lambda_                    :      0.100  +/-    0.04 1 / TeV
#     alpha      (frozen)        :      1.000
#     lon_0                      :    329.680  +/-    0.00 deg
#     lat_0                      :    -30.222  +/-    0.00 deg

# %% [markdown]
# ## Index

# %%
for m in models_no:
    par = m.parameters['index']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# index
# 2.3  \pm  0.09232 -0.09572  +0.09008
# index
# 2.227  \pm  0.08819 -0.09584  +0.0902
# index
# 2.3  \pm  0.09232 -0.09584  +0.0902

# %%
for m in models:
    par = m.parameters['index']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# index
# 2.302  \pm  0.09224 -0.09838  +0.09174
# index
# 2.299  \pm  0.1291 -0.1282  +0.1503
# index
# 2.299  \pm  0.1306 -0.13  +0.1512

# %% [markdown]
# ## amplitude

# %%
for m in models_no:
    par = m.parameters['amplitude']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# amplitude
# 3.85e-11  \pm  2.59e-12 -2.431e-12  +2.808e-12
# amplitude
# 4.057e-11  \pm  2.502e-12 -2.431e-12  +2.808e-12
# amplitude
# 3.85e-11  \pm  2.59e-12 -2.431e-12  +2.809e-12

# %%
for m in models:
    par = m.parameters['amplitude']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# amplitude
# 3.849e-11  \pm  5.934e-12 -5.334e-12  +6.439e-12
# amplitude
# 3.852e-11  \pm  2.607e-12 -2.578e-12  +3.051e-12
# amplitude
# 3.853e-11  \pm  5.967e-12 -5.407e-12  +6.566e-12

# %% [markdown]
# ## lambda_

# %%
for m in models_no:
    par = m.parameters['lambda_']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# lambda_
# 0.1  \pm  0.03995 -0.03707  +0.04356
# lambda_
# 0.138  \pm  0.03805 -0.03707  +0.04356
# lambda_
# 0.1  \pm  0.03995 -0.03706  +0.0436

# %%
for m in models:
    par = m.parameters['lambda_']
    print(par.name)
    try:
        print(f'{par.value:.4}  \pm  {par.error:.4} -{par.error_n:.4}  +{par.error_p:.4}')
    except:
        print(f'{par.value:.4}  \pm  {par.error:.4} ')
# Out:
# lambda_
# 0.09952  \pm  0.03891 -0.03695  +0.04345
# lambda_
# 0.09988  \pm  0.03984 -0.04084  +0.04653
# lambda_
# 0.09988  \pm  0.03984 -0.04095  +0.04644

# %%
from gammapy.modeling import Parameter
import numpy as np
def round_par(p):
    i = 2
    
    if p.name == 'amplitude':
        rounded_par = Parameter(value = np.round(p.value*1e11, decimals=i), 
                            error = np.round(p.error*1e11, decimals=i), 
                            error_n = np.round(p.error_n*1e11, decimals=i),
                            error_p = np.round(p.error_p*1e11, decimals=i),
                            name = p.name)
    
    else:
        rounded_par = Parameter(value = np.round(p.value, decimals=i), 
                            error = np.round(p.error, decimals=i), 
                            error_n = np.round(p.error_n, decimals=i),
                            error_p = np.round(p.error_p, decimals=i),
                            name = p.name)
    return rounded_par

# %%
headline = "\\textbf{Point Source} &  $\Phi_0\ [10^{-11}\, \\text{cm}^{-2}\, \\text{s}^{-1}\,\\text{TeV}^{-1}]$  & $\Gamma$ & $\lambda = 1/E_c\ [\\text{TeV}^{-1}]$  & $\sigma\, [\\text{deg}]$ \\\ \hline \hline"
input_ = ' Simulation input & $3.85 $  & $2.30 $  & $0.10 $ & --   \\\  \hline'


parameters = ['amplitude', 'index', 'lambda_']
text = ['no systematics ', 
        f'systematics on $A_{{\\text{{eff}}}}$',
       f'systematics on $E_{{\\text{{disp}}}}$',
       f'systematics on $A_{{\\text{{eff}}}}$ \& $E_{{\\text{{disp}}}}$',
       f'$20\%$ systematics on $A_{{\\text{{eff}}}}$',]

print_models = [models_no[0], models[0], models[1],  models[2],
               models_double[0]]


print(headline)
print(input_)
print()

for m, t in zip(print_models, text): 
    string = t
    for p_name in parameters:
        par = round_par(m.parameters[p_name])
        string += rf' & \error {{{par.value:.3}}} {{{par.error:.3}}}  {{{par.error_p:.3}}}  {{{par.error_n:.3}}} '
    string +=  '\\  \hline'
    print(string)
    print()
# Out:
# \textbf{Point Source} &  $\Phi_0\ [10^{-11}\, \text{cm}^{-2}\, \text{s}^{-1}\,\text{TeV}^{-1}]$  & $\Gamma$ & $\lambda = 1/E_c\ [\text{TeV}^{-1}]$  & $\sigma\, [\text{deg}]$ \\ \hline \hline
#  Simulation input & $3.85 $  & $2.30 $  & $0.10 $ & --   \\  \hline
#
# no systematics  & \error {3.85} {0.26}  {0.28}  {0.24}  & \error {2.3} {0.09}  {0.09}  {0.1}  & \error {0.1} {0.04}  {0.04}  {0.04} \  \hline
#
# systematics on $A_{\text{eff}}$ & \error {3.85} {0.59}  {0.64}  {0.53}  & \error {2.3} {0.09}  {0.09}  {0.1}  & \error {0.1} {0.04}  {0.04}  {0.04} \  \hline
#
# systematics on $E_{\text{disp}}$ & \error {3.85} {0.26}  {0.31}  {0.26}  & \error {2.3} {0.13}  {0.15}  {0.13}  & \error {0.1} {0.04}  {0.05}  {0.04} \  \hline
#
# systematics on $A_{\text{eff}}$ \& $E_{\text{disp}}$ & \error {3.85} {0.6}  {0.66}  {0.54}  & \error {2.3} {0.13}  {0.15}  {0.13}  & \error {0.1} {0.04}  {0.05}  {0.04} \  \hline
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 23
#      21 string = t
#      22 for p_name in parameters:
# ---> 23     par = round_par(m.parameters[p_name])
#      24     string += rf' & \error {{{par.value:.3}}} {{{par.error:.3}}}  {{{par.error_p:.3}}}  {{{par.error_n:.3}}} '
#      25 string +=  '\\  \hline'
#
# Cell In[14], line 9, in round_par(p)
#       4 i = 2
#       6 if p.name == 'amplitude':
#       7     rounded_par = Parameter(value = np.round(p.value*1e11, decimals=i),
#       8                         error = np.round(p.error*1e11, decimals=i),
# ----> 9                         error_n = np.round(p.error_n*1e11, decimals=i),
#      10                         error_p = np.round(p.error_p*1e11, decimals=i),
#      11                         name = p.name)
#      13 else:
#      14     rounded_par = Parameter(value = np.round(p.value, decimals=i),
#      15                         error = np.round(p.error, decimals=i),
#      16                         error_n = np.round(p.error_n, decimals=i),
#      17                         error_p = np.round(p.error_p, decimals=i),
#      18                         name = p.name)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'

# %% [markdown]
# ## Plots

# %%
ax = models_double[2][0].spectral_model.plot_error( facecolor = 'tab:blue',
                                               energy_power = epower)

models_double[2][0].spectral_model.plot_error( facecolor = 'tab:blue', label ="Com 20%",
                                          energy_power = epower, alpha = 1)

models_sym[2][0].spectral_model.plot_error( facecolor = 'tab:orange', label ="Com 10%",
                                          energy_power = epower, alpha = 1)


ax.legend()

# %%
ax = models_double[0][0].spectral_model.plot_error( facecolor = 'tab:blue',
                                               energy_power = epower)

models_double[0][0].spectral_model.plot_error( facecolor = 'tab:blue', label ="Eff 20%",
                                          energy_power = epower, alpha = 1)

models_sym[0][0].spectral_model.plot_error( facecolor = 'tab:orange', label ="Eff 10%",
                                          energy_power = epower, alpha = 1)


ax.legend()

# %%
ax = models_double[1][0].spectral_model.plot_error( facecolor = 'tab:blue',
                                               energy_power = epower)

models_double[1][0].spectral_model.plot_error( facecolor = 'tab:blue', label ="bias 20%",
                                          energy_power = epower, alpha = 1)

models_sym[1][0].spectral_model.plot_error( facecolor = 'tab:orange', label ="bias 10%",
                                          energy_power = epower, alpha = 1)


ax.legend()
